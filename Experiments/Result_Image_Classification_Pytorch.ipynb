# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

import scipy
from scipy.stats.stats import pearsonr
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from numpy import nan
from numpy import isnan
import statsmodels.api as sm

# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from numpy import nan
from numpy import isnan
import statsmodels.api as sm

# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

from sklearn.impute import SimpleImputer
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score


from sklearn.feature_selection import mutual_info_classif
from sklearn.datasets import make_classification
from sklearn.preprocessing import LabelEncoder
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# #1) Iris Dataset

# %%
# !pip install split-folders
from google.colab import drive
drive.mount('/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Mounted at /drive

# %%
# !gdown --id 1a_fWFbUDaQ9kmYxciAFlKmVO5CwG71SZ
#For zip Dataset Folders
# !unzip /content/IrisImageDataset.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1a_fWFbUDaQ9kmYxciAFlKmVO5CwG71SZ
# To: /content/IrisImageDataset.zip
# 100% 157k/157k [00:00<00:00, 95.8MB/s]
# Archive:  /content/IrisImageDataset.zip
#    creating: content/IrisImageDataset/
#    creating: content/IrisImageDataset/2/
#   inflating: content/IrisImageDataset/2/118.png
#   inflating: content/IrisImageDataset/2/104.png
#   inflating: content/IrisImageDataset/2/133.png
#   inflating: content/IrisImageDataset/2/127.png
#   inflating: content/IrisImageDataset/2/131.png
#   inflating: content/IrisImageDataset/2/100.png
#   inflating: content/IrisImageDataset/2/139.png
#   inflating: content/IrisImageDataset/2/113.png
#   inflating: content/IrisImageDataset/2/111.png
#   inflating: content/IrisImageDataset/2/137.png
#   inflating: content/IrisImageDataset/2/109.png
#   inflating: content/IrisImageDataset/2/147.png
#   inflating: content/IrisImageDataset/2/119.png
#   inflating: content/IrisImageDataset/2/140.png
#   inflating: content/IrisImageDataset/2/110.png
#   inflating: content/IrisImageDataset/2/101.png
#   inflating: content/IrisImageDataset/2/130.png
#   inflating: content/IrisImageDataset/2/132.png
#   inflating: content/IrisImageDataset/2/143.png
#   inflating: content/IrisImageDataset/2/115.png
#   inflating: content/IrisImageDataset/2/128.png
#   inflating: content/IrisImageDataset/2/120.png
#   inflating: content/IrisImageDataset/2/124.png
#   inflating: content/IrisImageDataset/2/116.png
#   inflating: content/IrisImageDataset/2/145.png
#   inflating: content/IrisImageDataset/2/103.png
#   inflating: content/IrisImageDataset/2/142.png
#   inflating: content/IrisImageDataset/2/106.png
#   inflating: content/IrisImageDataset/2/112.png
#   inflating: content/IrisImageDataset/2/108.png
#   inflating: content/IrisImageDataset/2/134.png
#   inflating: content/IrisImageDataset/2/136.png
#   inflating: content/IrisImageDataset/2/117.png
#   inflating: content/IrisImageDataset/2/122.png
#   inflating: content/IrisImageDataset/2/121.png
#   inflating: content/IrisImageDataset/2/149.png
#   inflating: content/IrisImageDataset/2/126.png
#   inflating: content/IrisImageDataset/2/125.png
#   inflating: content/IrisImageDataset/2/144.png
#   inflating: content/IrisImageDataset/2/114.png
#   inflating: content/IrisImageDataset/2/105.png
#   inflating: content/IrisImageDataset/0/47.png
#   inflating: content/IrisImageDataset/0/11.png
#   inflating: content/IrisImageDataset/0/32.png
#   inflating: content/IrisImageDataset/0/28.png
#   inflating: content/IrisImageDataset/0/33.png
#   inflating: content/IrisImageDataset/0/30.png
#   inflating: content/IrisImageDataset/0/0.png
#   inflating: content/IrisImageDataset/0/24.png
#   inflating: content/IrisImageDataset/0/37.png
#   inflating: content/IrisImageDataset/0/31.png
#   inflating: content/IrisImageDataset/0/46.png
#   inflating: content/IrisImageDataset/0/42.png
#   inflating: content/IrisImageDataset/0/17.png
#   inflating: content/IrisImageDataset/0/4.png
#   inflating: content/IrisImageDataset/0/48.png
#   inflating: content/IrisImageDataset/0/1.png
#   inflating: content/IrisImageDataset/0/49.png
#   inflating: content/IrisImageDataset/0/29.png
#   inflating: content/IrisImageDataset/0/18.png
#   inflating: content/IrisImageDataset/0/16.png
#   inflating: content/IrisImageDataset/0/15.png
#   inflating: content/IrisImageDataset/0/19.png
#   inflating: content/IrisImageDataset/0/22.png
#   inflating: content/IrisImageDataset/0/6.png
#   inflating: content/IrisImageDataset/0/3.png
#   inflating: content/IrisImageDataset/0/39.png
#   inflating: content/IrisImageDataset/0/26.png
#   inflating: content/IrisImageDataset/0/36.png
#   inflating: content/IrisImageDataset/0/44.png
#   inflating: content/IrisImageDataset/0/20.png
#   inflating: content/IrisImageDataset/0/45.png
#   inflating: content/IrisImageDataset/0/41.png
#   inflating: content/IrisImageDataset/0/43.png
#   inflating: content/IrisImageDataset/0/13.png
#   inflating: content/IrisImageDataset/0/27.png
#   inflating: content/IrisImageDataset/0/5.png
#   inflating: content/IrisImageDataset/0/9.png
#   inflating: content/IrisImageDataset/0/12.png
#   inflating: content/IrisImageDataset/0/23.png
#   inflating: content/IrisImageDataset/0/21.png
#   inflating: content/IrisImageDataset/0/40.png
#   inflating: content/IrisImageDataset/0/2.png
#   inflating: content/IrisImageDataset/0/7.png
#   inflating: content/IrisImageDataset/0/14.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/IrisImageDataset", output="/content/content/IrisSplit", seed=1337, ratio=(.90,  .10), group_prefix=None) # default values
# Out:
# Copying files: 150 files [00:00, 6134.30 files/s]

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
os.listdir("/content/content/IrisSplit")
# Out:
# ['train', 'val']

# %% [markdown]
# ##DataLoaders

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/IrisSplit'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 135, 'val': 15}, ['0', '1', '2'], device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ##Training, Testing and Evaluation

# %% [markdown]
# ###Resnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=10)
# Out:
# Epoch 0/9
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.4154 Acc: 0.8444
# val Loss: 0.4251 Acc: 0.8667
#
# Epoch 1/9
# ----------
# train Loss: 0.1577 Acc: 0.9481
# val Loss: 0.3310 Acc: 0.8667
#
# Epoch 2/9
# ----------
# train Loss: 0.1269 Acc: 0.9630
# val Loss: 0.2370 Acc: 0.9333
#
# Epoch 3/9
# ----------
# train Loss: 0.0615 Acc: 0.9852
# val Loss: 0.2343 Acc: 0.9333
#
# Epoch 4/9
# ----------
# train Loss: 0.0378 Acc: 0.9852
# val Loss: 0.1431 Acc: 0.9333
#
# Epoch 5/9
# ----------
# train Loss: 0.0160 Acc: 0.9926
# val Loss: 0.1103 Acc: 0.9333
#
# Epoch 6/9
# ----------
# train Loss: 0.0238 Acc: 0.9852
# val Loss: 0.0937 Acc: 0.9333
#
# Epoch 7/9
# ----------
# train Loss: 0.0201 Acc: 0.9926
# val Loss: 0.0882 Acc: 0.9333
#
# Epoch 8/9
# ----------
# train Loss: 0.0186 Acc: 1.0000
# val Loss: 0.0757 Acc: 0.9333
#
# Epoch 9/9
# ----------
# train Loss: 0.0138 Acc: 1.0000
# val Loss: 0.0698 Acc: 0.9333
#
# Training complete in 0m 12s
# Best val Acc: 0.933333

# %%
torch.save(model_ft, "Iris_Resnet18.pth")
model_ft = torch.load("/content/Iris_Resnet18.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# ###Densenet

# %%
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 3.1071 Acc: 0.7926
# val Loss: 18.1377 Acc: 0.3333
#
# Epoch 1/19
# ----------
# train Loss: 0.1474 Acc: 0.9704
# val Loss: 6.3226 Acc: 0.3333
#
# Epoch 2/19
# ----------
# train Loss: 0.0734 Acc: 0.9852
# val Loss: 0.1776 Acc: 1.0000
#
# Epoch 3/19
# ----------
# train Loss: 0.0580 Acc: 0.9852
# val Loss: 0.0322 Acc: 1.0000
#
# Epoch 4/19
# ----------
# train Loss: 0.0461 Acc: 0.9778
# val Loss: 0.0312 Acc: 1.0000
#
# Epoch 5/19
# ----------
# train Loss: 0.0319 Acc: 1.0000
# val Loss: 0.0313 Acc: 1.0000
#
# Epoch 6/19
# ----------
# train Loss: 0.0302 Acc: 1.0000
# val Loss: 0.0346 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0444 Acc: 0.9926
# val Loss: 0.0281 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0429 Acc: 1.0000
# val Loss: 0.0298 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0427 Acc: 0.9926
# val Loss: 0.0329 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0212 Acc: 1.0000
# val Loss: 0.0332 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0185 Acc: 1.0000
# val Loss: 0.0319 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0253 Acc: 1.0000
# val Loss: 0.0321 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0350 Acc: 1.0000
# val Loss: 0.0307 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0592 Acc: 0.9852
# val Loss: 0.0329 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0278 Acc: 1.0000
# val Loss: 0.0315 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0515 Acc: 0.9852
# val Loss: 0.0284 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0311 Acc: 1.0000
# val Loss: 0.0304 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0622 Acc: 0.9852
# val Loss: 0.0328 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0343 Acc: 1.0000
# val Loss: 0.0312 Acc: 1.0000
#
# Training complete in 0m 34s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Iris_Densenet.pth")
model_ft = torch.load("/content/Iris_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# ###Inception V1

# %%
model_ft = models.googlenet(pretrained=False)
model_ft.aux_logits = False 
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/googlenet.py:50: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   FutureWarning,

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 0.7826 Acc: 0.6889
# val Loss: 1.5407 Acc: 0.3333
#
# Epoch 1/19
# ----------
# train Loss: 0.2734 Acc: 0.9111
# val Loss: 3.0043 Acc: 0.3333
#
# Epoch 2/19
# ----------
# train Loss: 0.2350 Acc: 0.9259
# val Loss: 3.0090 Acc: 0.3333
#
# Epoch 3/19
# ----------
# train Loss: 0.2378 Acc: 0.9407
# val Loss: 3.2603 Acc: 0.3333
#
# Epoch 4/19
# ----------
# train Loss: 0.2621 Acc: 0.9185
# val Loss: 2.6407 Acc: 0.2000
#
# Epoch 5/19
# ----------
# train Loss: 0.1313 Acc: 0.9556
# val Loss: 0.3249 Acc: 0.8667
#
# Epoch 6/19
# ----------
# train Loss: 0.1291 Acc: 0.9556
# val Loss: 0.1274 Acc: 0.9333
#
# Epoch 7/19
# ----------
# train Loss: 0.1430 Acc: 0.9556
# val Loss: 0.0660 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0976 Acc: 0.9704
# val Loss: 0.0645 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0992 Acc: 0.9630
# val Loss: 0.0474 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0800 Acc: 0.9778
# val Loss: 0.0526 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.1057 Acc: 0.9556
# val Loss: 0.0452 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0967 Acc: 0.9630
# val Loss: 0.0476 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0917 Acc: 0.9704
# val Loss: 0.0499 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0810 Acc: 0.9630
# val Loss: 0.0481 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0943 Acc: 0.9630
# val Loss: 0.0433 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.1034 Acc: 0.9630
# val Loss: 0.0460 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.1123 Acc: 0.9481
# val Loss: 0.0498 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.1091 Acc: 0.9630
# val Loss: 0.0429 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.1053 Acc: 0.9630
# val Loss: 0.0389 Acc: 1.0000
#
# Training complete in 0m 22s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Iris_Inception.pth")
model_ft = torch.load("/content/Iris_Inception.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# # 2) Wine Dataset

# %%
# !gdown --id 1Nk1ymYTjBzKvyvbTOqUUelJBq9UG4MG7
#For zip Dataset Folders
# !unzip /content/WineImageDataset.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1Nk1ymYTjBzKvyvbTOqUUelJBq9UG4MG7
# To: /content/WineImageDataset.zip
# 100% 281k/281k [00:00<00:00, 119MB/s]
# Archive:  /content/WineImageDataset.zip
#    creating: content/WineImageDataset/
#    creating: content/WineImageDataset/2/
#  extracting: content/WineImageDataset/2/118.png
#  extracting: content/WineImageDataset/2/60.png
#  extracting: content/WineImageDataset/2/104.png
#  extracting: content/WineImageDataset/2/63.png
#  extracting: content/WineImageDataset/2/127.png
#  extracting: content/WineImageDataset/2/61.png
#  extracting: content/WineImageDataset/2/100.png
#  extracting: content/WineImageDataset/2/113.png
#  extracting: content/WineImageDataset/2/111.png
#  extracting: content/WineImageDataset/2/109.png
#  extracting: content/WineImageDataset/2/99.png
#  extracting: content/WineImageDataset/2/119.png
#  extracting: content/WineImageDataset/2/90.png
#  extracting: content/WineImageDataset/2/66.png
#  extracting: content/WineImageDataset/2/110.png
#  extracting: content/WineImageDataset/2/68.png
#  extracting: content/WineImageDataset/2/73.png
#  extracting: content/WineImageDataset/2/74.png
#  extracting: content/WineImageDataset/2/101.png
#  extracting: content/WineImageDataset/2/115.png
#  extracting: content/WineImageDataset/2/128.png
#  extracting: content/WineImageDataset/2/120.png
#  extracting: content/WineImageDataset/2/91.png
#  extracting: content/WineImageDataset/2/82.png
#  extracting: content/WineImageDataset/2/95.png
#  extracting: content/WineImageDataset/2/124.png
#  extracting: content/WineImageDataset/2/116.png
#  extracting: content/WineImageDataset/2/72.png
#  extracting: content/WineImageDataset/2/92.png
#  extracting: content/WineImageDataset/2/103.png
#  extracting: content/WineImageDataset/2/87.png
#  extracting: content/WineImageDataset/2/106.png
#  extracting: content/WineImageDataset/2/97.png
#  extracting: content/WineImageDataset/2/112.png
#  extracting: content/WineImageDataset/2/108.png
#  extracting: content/WineImageDataset/2/84.png
#  extracting: content/WineImageDataset/2/117.png
#  extracting: content/WineImageDataset/2/76.png
#  extracting: content/WineImageDataset/2/122.png
#  extracting: content/WineImageDataset/2/121.png
#  extracting: content/WineImageDataset/2/85.png
#  extracting: content/WineImageDataset/2/64.png
#  extracting: content/WineImageDataset/2/126.png
#  extracting: content/WineImageDataset/2/94.png
#  extracting: content/WineImageDataset/2/125.png
#  extracting: content/WineImageDataset/3/138.png
#  extracting: content/WineImageDataset/3/146.png
#  extracting: content/WineImageDataset/3/171.png
#  extracting: content/WineImageDataset/3/135.png
#  extracting: content/WineImageDataset/3/141.png
#  extracting: content/WineImageDataset/3/166.png
#    creating: content/WineImageDataset/1/
#  extracting: content/WineImageDataset/1/25.png
#  extracting: content/WineImageDataset/1/56.png
#  extracting: content/WineImageDataset/1/35.png
#  extracting: content/WineImageDataset/1/38.png
#  extracting: content/WineImageDataset/1/8.png
#  extracting: content/WineImageDataset/1/10.png
#  extracting: content/WineImageDataset/1/34.png
#  extracting: content/WineImageDataset/1/47.png
#  extracting: content/WineImageDataset/1/11.png
#  extracting: content/WineImageDataset/1/58.png
#  extracting: content/WineImageDataset/1/32.png
#  extracting: content/WineImageDataset/1/28.png
#  extracting: content/WineImageDataset/1/33.png
#  extracting: content/WineImageDataset/1/30.png
#  extracting: content/WineImageDataset/1/0.png
#  extracting: content/WineImageDataset/1/24.png
#  extracting: content/WineImageDataset/1/54.png
#  extracting: content/WineImageDataset/1/37.png
#  extracting: content/WineImageDataset/1/31.png
#  extracting: content/WineImageDataset/1/46.png
#  extracting: content/WineImageDataset/1/42.png
#  extracting: content/WineImageDataset/1/17.png
#  extracting: content/WineImageDataset/1/4.png
#  extracting: content/WineImageDataset/1/48.png
#  extracting: content/WineImageDataset/1/1.png
#  extracting: content/WineImageDataset/1/49.png
#  extracting: content/WineImageDataset/1/29.png
#  extracting: content/WineImageDataset/1/18.png
#  extracting: content/WineImageDataset/1/16.png
#  extracting: content/WineImageDataset/1/15.png
#  extracting: content/WineImageDataset/1/19.png
#  extracting: content/WineImageDataset/1/57.png
#  extracting: content/WineImageDataset/1/22.png
#  extracting: content/WineImageDataset/1/55.png
#  extracting: content/WineImageDataset/1/6.png
#  extracting: content/WineImageDataset/1/3.png
#  extracting: content/WineImageDataset/1/53.png
#  extracting: content/WineImageDataset/1/39.png
#  extracting: content/WineImageDataset/1/26.png
#  extracting: content/WineImageDataset/1/36.png
#  extracting: content/WineImageDataset/1/44.png
#  extracting: content/WineImageDataset/1/20.png
#  extracting: content/WineImageDataset/1/45.png
#  extracting: content/WineImageDataset/1/41.png
#  extracting: content/WineImageDataset/1/51.png
#  extracting: content/WineImageDataset/1/43.png
#  extracting: content/WineImageDataset/1/13.png
#  extracting: content/WineImageDataset/1/27.png
#  extracting: content/WineImageDataset/1/5.png
#  extracting: content/WineImageDataset/1/50.png
#  extracting: content/WineImageDataset/1/9.png
#  extracting: content/WineImageDataset/1/12.png
#  extracting: content/WineImageDataset/1/23.png
#  extracting: content/WineImageDataset/1/21.png
#  extracting: content/WineImageDataset/1/40.png
#  extracting: content/WineImageDataset/1/2.png
#  extracting: content/WineImageDataset/1/7.png
#  extracting: content/WineImageDataset/1/52.png
#  extracting: content/WineImageDataset/1/14.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/WineImageDataset", output="/content/content/WineSplit",  seed=1337, ratio=(.85,  .15), group_prefix=None) # default values
# Out:
# Copying files: 178 files [00:00, 8227.12 files/s]

# %%
os.listdir("/content/content/WineSplit")
# Out:
# ['train', 'val']

# %% [markdown]
# ##DataLoaders

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/WineSplit'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 150, 'val': 28}, ['1', '2', '3'], device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ##Training, Testing and Evaluation

# %% [markdown]
# ###Resnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=10)
# Out:
# Epoch 0/9
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.4448 Acc: 0.8067
# val Loss: 0.1322 Acc: 0.9643
#
# Epoch 1/9
# ----------
# train Loss: 0.0333 Acc: 0.9800
# val Loss: 0.0072 Acc: 1.0000
#
# Epoch 2/9
# ----------
# train Loss: 0.0052 Acc: 1.0000
# val Loss: 0.0022 Acc: 1.0000
#
# Epoch 3/9
# ----------
# train Loss: 0.0032 Acc: 1.0000
# val Loss: 0.0021 Acc: 1.0000
#
# Epoch 4/9
# ----------
# train Loss: 0.0039 Acc: 1.0000
# val Loss: 0.0019 Acc: 1.0000
#
# Epoch 5/9
# ----------
# train Loss: 0.0030 Acc: 1.0000
# val Loss: 0.0019 Acc: 1.0000
#
# Epoch 6/9
# ----------
# train Loss: 0.0033 Acc: 1.0000
# val Loss: 0.0019 Acc: 1.0000
#
# Epoch 7/9
# ----------
# train Loss: 0.0044 Acc: 1.0000
# val Loss: 0.0022 Acc: 1.0000
#
# Epoch 8/9
# ----------
# train Loss: 0.0137 Acc: 1.0000
# val Loss: 0.0016 Acc: 1.0000
#
# Epoch 9/9
# ----------
# train Loss: 0.0074 Acc: 1.0000
# val Loss: 0.0021 Acc: 1.0000
#
# Training complete in 0m 10s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Wine_Resnet18.pth")
model_ft = torch.load("/content/Wine_Resnet18.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# ###Densenet

# %%
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 3.5057 Acc: 0.6267
# val Loss: 4.6634 Acc: 0.2857
#
# Epoch 1/4
# ----------
# train Loss: 0.2085 Acc: 0.9800
# val Loss: 1.3584 Acc: 0.3214
#
# Epoch 2/4
# ----------
# train Loss: 0.0367 Acc: 1.0000
# val Loss: 0.0290 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0249 Acc: 1.0000
# val Loss: 0.0203 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0145 Acc: 1.0000
# val Loss: 0.0208 Acc: 1.0000
#
# Training complete in 0m 10s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Wine_Densenet.pth")
model_ft = torch.load("/content/Wine_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# ###Inception V1

# %%
model_ft = models.googlenet(pretrained=False)
model_ft.aux_logits = False 
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/googlenet.py:50: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   FutureWarning,

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 1.0465 Acc: 0.5333
# val Loss: 1.2584 Acc: 0.3214
#
# Epoch 1/19
# ----------
# train Loss: 0.5897 Acc: 0.7600
# val Loss: 4.6287 Acc: 0.3214
#
# Epoch 2/19
# ----------
# train Loss: 0.2254 Acc: 0.9267
# val Loss: 5.5582 Acc: 0.3214
#
# Epoch 3/19
# ----------
# train Loss: 0.1626 Acc: 0.9267
# val Loss: 3.9080 Acc: 0.3214
#
# Epoch 4/19
# ----------
# train Loss: 0.0897 Acc: 0.9667
# val Loss: 1.3947 Acc: 0.4286
#
# Epoch 5/19
# ----------
# train Loss: 0.0513 Acc: 0.9800
# val Loss: 0.1521 Acc: 0.9286
#
# Epoch 6/19
# ----------
# train Loss: 0.0237 Acc: 0.9933
# val Loss: 0.0433 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0496 Acc: 0.9933
# val Loss: 0.0162 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0168 Acc: 1.0000
# val Loss: 0.0115 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0219 Acc: 0.9933
# val Loss: 0.0124 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0085 Acc: 1.0000
# val Loss: 0.0097 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0160 Acc: 1.0000
# val Loss: 0.0101 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0257 Acc: 0.9933
# val Loss: 0.0093 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0144 Acc: 1.0000
# val Loss: 0.0093 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0166 Acc: 0.9933
# val Loss: 0.0089 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0234 Acc: 1.0000
# val Loss: 0.0091 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0108 Acc: 1.0000
# val Loss: 0.0092 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0101 Acc: 1.0000
# val Loss: 0.0093 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0271 Acc: 0.9933
# val Loss: 0.0088 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0165 Acc: 1.0000
# val Loss: 0.0093 Acc: 1.0000
#
# Training complete in 0m 25s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Wine_Inception.pth")
model_ft = torch.load("/content/Wine_Inception.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# # 3) Breast Cancer

# %%
# !gdown --id 1-QHXj_3al84vRUM3lQW5lvZbCC8854XT
#For zip Dataset Folders
# !unzip /content/BreastCancerImageDataset.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1-QHXj_3al84vRUM3lQW5lvZbCC8854XT
# To: /content/BreastCancerImageDataset.zip
# 100% 645k/645k [00:00<00:00, 83.5MB/s]
# Archive:  /content/BreastCancerImageDataset.zip
#    creating: content/BreastCancerImageDataset/
#    creating: content/BreastCancerImageDataset/2/
#  extracting: content/BreastCancerImageDataset/2/158.png
#  extracting: content/BreastCancerImageDataset/2/118.png
#  extracting: content/BreastCancerImageDataset/2/245.png
#   inflating: content/BreastCancerImageDataset/2/686.png
#  extracting: content/BreastCancerImageDataset/2/133.png
#  extracting: content/BreastCancerImageDataset/2/35.png
#  extracting: content/BreastCancerImageDataset/2/388.png
#  extracting: content/BreastCancerImageDataset/2/303.png
#  extracting: content/BreastCancerImageDataset/2/486.png
#  extracting: content/BreastCancerImageDataset/2/682.png
#  extracting: content/BreastCancerImageDataset/2/430.png
#  extracting: content/BreastCancerImageDataset/2/561.png
#  extracting: content/BreastCancerImageDataset/2/127.png
#  extracting: content/BreastCancerImageDataset/2/8.png
#  extracting: content/BreastCancerImageDataset/2/131.png
#  extracting: content/BreastCancerImageDataset/2/61.png
#  extracting: content/BreastCancerImageDataset/2/469.png
#  extracting: content/BreastCancerImageDataset/2/656.png
#  extracting: content/BreastCancerImageDataset/2/663.png
#  extracting: content/BreastCancerImageDataset/2/398.png
#   inflating: content/BreastCancerImageDataset/2/446.png
#  extracting: content/BreastCancerImageDataset/2/139.png
#   inflating: content/BreastCancerImageDataset/2/10.png
#  extracting: content/BreastCancerImageDataset/2/560.png
#  extracting: content/BreastCancerImageDataset/2/259.png
#  extracting: content/BreastCancerImageDataset/2/307.png
#  extracting: content/BreastCancerImageDataset/2/497.png
#  extracting: content/BreastCancerImageDataset/2/352.png
#  extracting: content/BreastCancerImageDataset/2/196.png
#  extracting: content/BreastCancerImageDataset/2/34.png
#  extracting: content/BreastCancerImageDataset/2/492.png
#  extracting: content/BreastCancerImageDataset/2/164.png
#  extracting: content/BreastCancerImageDataset/2/163.png
#  extracting: content/BreastCancerImageDataset/2/365.png
#  extracting: content/BreastCancerImageDataset/2/630.png
#  extracting: content/BreastCancerImageDataset/2/157.png
#  extracting: content/BreastCancerImageDataset/2/634.png
#  extracting: content/BreastCancerImageDataset/2/661.png
#  extracting: content/BreastCancerImageDataset/2/584.png
#  extracting: content/BreastCancerImageDataset/2/204.png
#  extracting: content/BreastCancerImageDataset/2/137.png
#  extracting: content/BreastCancerImageDataset/2/470.png
#  extracting: content/BreastCancerImageDataset/2/543.png
#   inflating: content/BreastCancerImageDataset/2/47.png
#  extracting: content/BreastCancerImageDataset/2/319.png
#  extracting: content/BreastCancerImageDataset/2/11.png
#  extracting: content/BreastCancerImageDataset/2/464.png
#  extracting: content/BreastCancerImageDataset/2/220.png
#  extracting: content/BreastCancerImageDataset/2/676.png
#  extracting: content/BreastCancerImageDataset/2/193.png
#  extracting: content/BreastCancerImageDataset/2/535.png
#   inflating: content/BreastCancerImageDataset/2/607.png
#  extracting: content/BreastCancerImageDataset/2/249.png
#   inflating: content/BreastCancerImageDataset/2/448.png
#  extracting: content/BreastCancerImageDataset/2/409.png
#  extracting: content/BreastCancerImageDataset/2/194.png
#  extracting: content/BreastCancerImageDataset/2/547.png
#   inflating: content/BreastCancerImageDataset/2/407.png
#  extracting: content/BreastCancerImageDataset/2/325.png
#  extracting: content/BreastCancerImageDataset/2/346.png
#  extracting: content/BreastCancerImageDataset/2/269.png
#   inflating: content/BreastCancerImageDataset/2/225.png
#  extracting: content/BreastCancerImageDataset/2/478.png
#  extracting: content/BreastCancerImageDataset/2/481.png
#  extracting: content/BreastCancerImageDataset/2/147.png
#  extracting: content/BreastCancerImageDataset/2/209.png
#  extracting: content/BreastCancerImageDataset/2/363.png
#   inflating: content/BreastCancerImageDataset/2/172.png
#   inflating: content/BreastCancerImageDataset/2/659.png
#   inflating: content/BreastCancerImageDataset/2/480.png
#  extracting: content/BreastCancerImageDataset/2/119.png
#  extracting: content/BreastCancerImageDataset/2/371.png
#  extracting: content/BreastCancerImageDataset/2/526.png
#  extracting: content/BreastCancerImageDataset/2/641.png
#  extracting: content/BreastCancerImageDataset/2/90.png
#  extracting: content/BreastCancerImageDataset/2/28.png
#   inflating: content/BreastCancerImageDataset/2/517.png
#  extracting: content/BreastCancerImageDataset/2/461.png
#  extracting: content/BreastCancerImageDataset/2/192.png
#  extracting: content/BreastCancerImageDataset/2/439.png
#  extracting: content/BreastCancerImageDataset/2/394.png
#  extracting: content/BreastCancerImageDataset/2/341.png
#   inflating: content/BreastCancerImageDataset/2/327.png
#  extracting: content/BreastCancerImageDataset/2/275.png
#  extracting: content/BreastCancerImageDataset/2/548.png
#  extracting: content/BreastCancerImageDataset/2/140.png
#  extracting: content/BreastCancerImageDataset/2/258.png
#  extracting: content/BreastCancerImageDataset/2/450.png
#  extracting: content/BreastCancerImageDataset/2/66.png
#  extracting: content/BreastCancerImageDataset/2/444.png
#  extracting: content/BreastCancerImageDataset/2/287.png
#   inflating: content/BreastCancerImageDataset/2/216.png
#  extracting: content/BreastCancerImageDataset/2/651.png
#  extracting: content/BreastCancerImageDataset/2/672.png
#  extracting: content/BreastCancerImageDataset/2/110.png
#  extracting: content/BreastCancerImageDataset/2/250.png
#  extracting: content/BreastCancerImageDataset/2/33.png
#  extracting: content/BreastCancerImageDataset/2/271.png
#  extracting: content/BreastCancerImageDataset/2/176.png
#   inflating: content/BreastCancerImageDataset/2/314.png
#  extracting: content/BreastCancerImageDataset/2/318.png
#  extracting: content/BreastCancerImageDataset/2/454.png
#  extracting: content/BreastCancerImageDataset/2/474.png
#  extracting: content/BreastCancerImageDataset/2/389.png
#  extracting: content/BreastCancerImageDataset/2/688.png
#  extracting: content/BreastCancerImageDataset/2/502.png
#  extracting: content/BreastCancerImageDataset/2/524.png
#  extracting: content/BreastCancerImageDataset/2/130.png
#  extracting: content/BreastCancerImageDataset/2/30.png
#  extracting: content/BreastCancerImageDataset/2/432.png
#  extracting: content/BreastCancerImageDataset/2/392.png
#  extracting: content/BreastCancerImageDataset/2/664.png
#  extracting: content/BreastCancerImageDataset/2/695.png
#  extracting: content/BreastCancerImageDataset/2/244.png
#   inflating: content/BreastCancerImageDataset/2/683.png
#   inflating: content/BreastCancerImageDataset/2/290.png
#  extracting: content/BreastCancerImageDataset/2/553.png
#  extracting: content/BreastCancerImageDataset/2/120.png
#  extracting: content/BreastCancerImageDataset/2/91.png
#  extracting: content/BreastCancerImageDataset/2/82.png
#  extracting: content/BreastCancerImageDataset/2/599.png
#  extracting: content/BreastCancerImageDataset/2/477.png
#  extracting: content/BreastCancerImageDataset/2/95.png
#   inflating: content/BreastCancerImageDataset/2/376.png
#  extracting: content/BreastCancerImageDataset/2/153.png
#   inflating: content/BreastCancerImageDataset/2/504.png
#  extracting: content/BreastCancerImageDataset/2/434.png
#   inflating: content/BreastCancerImageDataset/2/632.png
#  extracting: content/BreastCancerImageDataset/2/395.png
#  extracting: content/BreastCancerImageDataset/2/458.png
#   inflating: content/BreastCancerImageDataset/2/180.png
#  extracting: content/BreastCancerImageDataset/2/217.png
#  extracting: content/BreastCancerImageDataset/2/116.png
#  extracting: content/BreastCancerImageDataset/2/72.png
#  extracting: content/BreastCancerImageDataset/2/48.png
#  extracting: content/BreastCancerImageDataset/2/649.png
#   inflating: content/BreastCancerImageDataset/2/665.png
#  extracting: content/BreastCancerImageDataset/2/566.png
#   inflating: content/BreastCancerImageDataset/2/674.png
#  extracting: content/BreastCancerImageDataset/2/622.png
#  extracting: content/BreastCancerImageDataset/2/476.png
#  extracting: content/BreastCancerImageDataset/2/294.png
#  extracting: content/BreastCancerImageDataset/2/243.png
#   inflating: content/BreastCancerImageDataset/2/520.png
#  extracting: content/BreastCancerImageDataset/2/92.png
#   inflating: content/BreastCancerImageDataset/2/150.png
#  extracting: content/BreastCancerImageDataset/2/536.png
#  extracting: content/BreastCancerImageDataset/2/379.png
#  extracting: content/BreastCancerImageDataset/2/485.png
#  extracting: content/BreastCancerImageDataset/2/1.png
#  extracting: content/BreastCancerImageDataset/2/29.png
#  extracting: content/BreastCancerImageDataset/2/145.png
#  extracting: content/BreastCancerImageDataset/2/647.png
#  extracting: content/BreastCancerImageDataset/2/332.png
#  extracting: content/BreastCancerImageDataset/2/527.png
#  extracting: content/BreastCancerImageDataset/2/331.png
#  extracting: content/BreastCancerImageDataset/2/596.png
#  extracting: content/BreastCancerImageDataset/2/652.png
#  extracting: content/BreastCancerImageDataset/2/370.png
#  extracting: content/BreastCancerImageDataset/2/415.png
#  extracting: content/BreastCancerImageDataset/2/185.png
#  extracting: content/BreastCancerImageDataset/2/16.png
#  extracting: content/BreastCancerImageDataset/2/459.png
#   inflating: content/BreastCancerImageDataset/2/380.png
#  extracting: content/BreastCancerImageDataset/2/403.png
#  extracting: content/BreastCancerImageDataset/2/97.png
#  extracting: content/BreastCancerImageDataset/2/600.png
#  extracting: content/BreastCancerImageDataset/2/693.png
#  extracting: content/BreastCancerImageDataset/2/528.png
#   inflating: content/BreastCancerImageDataset/2/496.png
#  extracting: content/BreastCancerImageDataset/2/399.png
#  extracting: content/BreastCancerImageDataset/2/364.png
#  extracting: content/BreastCancerImageDataset/2/252.png
#  extracting: content/BreastCancerImageDataset/2/390.png
#  extracting: content/BreastCancerImageDataset/2/667.png
#  extracting: content/BreastCancerImageDataset/2/108.png
#  extracting: content/BreastCancerImageDataset/2/613.png
#  extracting: content/BreastCancerImageDataset/2/19.png
#  extracting: content/BreastCancerImageDataset/2/240.png
#  extracting: content/BreastCancerImageDataset/2/447.png
#  extracting: content/BreastCancerImageDataset/2/134.png
#  extracting: content/BreastCancerImageDataset/2/22.png
#  extracting: content/BreastCancerImageDataset/2/6.png
#  extracting: content/BreastCancerImageDataset/2/640.png
#  extracting: content/BreastCancerImageDataset/2/401.png
#  extracting: content/BreastCancerImageDataset/2/475.png
#  extracting: content/BreastCancerImageDataset/2/422.png
#  extracting: content/BreastCancerImageDataset/2/306.png
#  extracting: content/BreastCancerImageDataset/2/136.png
#  extracting: content/BreastCancerImageDataset/2/666.png
#  extracting: content/BreastCancerImageDataset/2/337.png
#  extracting: content/BreastCancerImageDataset/2/350.png
#  extracting: content/BreastCancerImageDataset/2/589.png
#  extracting: content/BreastCancerImageDataset/2/671.png
#   inflating: content/BreastCancerImageDataset/2/277.png
#   inflating: content/BreastCancerImageDataset/2/338.png
#  extracting: content/BreastCancerImageDataset/2/690.png
#  extracting: content/BreastCancerImageDataset/2/615.png
#  extracting: content/BreastCancerImageDataset/2/443.png
#  extracting: content/BreastCancerImageDataset/2/644.png
#  extracting: content/BreastCancerImageDataset/2/551.png
#  extracting: content/BreastCancerImageDataset/2/324.png
#  extracting: content/BreastCancerImageDataset/2/3.png
#  extracting: content/BreastCancerImageDataset/2/396.png
#  extracting: content/BreastCancerImageDataset/2/423.png
#  extracting: content/BreastCancerImageDataset/2/76.png
#  extracting: content/BreastCancerImageDataset/2/507.png
#  extracting: content/BreastCancerImageDataset/2/309.png
#   inflating: content/BreastCancerImageDataset/2/410.png
#  extracting: content/BreastCancerImageDataset/2/538.png
#  extracting: content/BreastCancerImageDataset/2/274.png
#  extracting: content/BreastCancerImageDataset/2/433.png
#  extracting: content/BreastCancerImageDataset/2/424.png
#  extracting: content/BreastCancerImageDataset/2/298.png
#  extracting: content/BreastCancerImageDataset/2/629.png
#  extracting: content/BreastCancerImageDataset/2/265.png
#  extracting: content/BreastCancerImageDataset/2/521.png
#  extracting: content/BreastCancerImageDataset/2/662.png
#   inflating: content/BreastCancerImageDataset/2/347.png
#  extracting: content/BreastCancerImageDataset/2/575.png
#   inflating: content/BreastCancerImageDataset/2/510.png
#  extracting: content/BreastCancerImageDataset/2/219.png
#  extracting: content/BreastCancerImageDataset/2/26.png
#  extracting: content/BreastCancerImageDataset/2/121.png
#  extracting: content/BreastCancerImageDataset/2/387.png
#  extracting: content/BreastCancerImageDataset/2/451.png
#  extracting: content/BreastCancerImageDataset/2/462.png
#  extracting: content/BreastCancerImageDataset/2/498.png
#  extracting: content/BreastCancerImageDataset/2/512.png
#  extracting: content/BreastCancerImageDataset/2/441.png
#   inflating: content/BreastCancerImageDataset/2/129.png
#  extracting: content/BreastCancerImageDataset/2/509.png
#   inflating: content/BreastCancerImageDataset/2/405.png
#  extracting: content/BreastCancerImageDataset/2/102.png
#  extracting: content/BreastCancerImageDataset/2/408.png
#  extracting: content/BreastCancerImageDataset/2/182.png
#  extracting: content/BreastCancerImageDataset/2/383.png
#   inflating: content/BreastCancerImageDataset/2/169.png
#  extracting: content/BreastCancerImageDataset/2/148.png
#   inflating: content/BreastCancerImageDataset/2/660.png
#  extracting: content/BreastCancerImageDataset/2/170.png
#   inflating: content/BreastCancerImageDataset/2/198.png
#  extracting: content/BreastCancerImageDataset/2/88.png
#  extracting: content/BreastCancerImageDataset/2/197.png
#  extracting: content/BreastCancerImageDataset/2/689.png
#  extracting: content/BreastCancerImageDataset/2/13.png
#   inflating: content/BreastCancerImageDataset/2/578.png
#   inflating: content/BreastCancerImageDataset/2/643.png
#  extracting: content/BreastCancerImageDataset/2/508.png
#  extracting: content/BreastCancerImageDataset/2/635.png
#  extracting: content/BreastCancerImageDataset/2/83.png
#  extracting: content/BreastCancerImageDataset/2/419.png
#  extracting: content/BreastCancerImageDataset/2/452.png
#  extracting: content/BreastCancerImageDataset/2/291.png
#  extracting: content/BreastCancerImageDataset/2/580.png
#   inflating: content/BreastCancerImageDataset/2/93.png
#  extracting: content/BreastCancerImageDataset/2/583.png
#  extracting: content/BreastCancerImageDataset/2/77.png
#   inflating: content/BreastCancerImageDataset/2/685.png
#  extracting: content/BreastCancerImageDataset/2/385.png
#  extracting: content/BreastCancerImageDataset/2/404.png
#  extracting: content/BreastCancerImageDataset/2/310.png
#  extracting: content/BreastCancerImageDataset/2/342.png
#  extracting: content/BreastCancerImageDataset/2/69.png
#  extracting: content/BreastCancerImageDataset/2/80.png
#  extracting: content/BreastCancerImageDataset/2/402.png
#  extracting: content/BreastCancerImageDataset/2/511.png
#  extracting: content/BreastCancerImageDataset/2/202.png
#  extracting: content/BreastCancerImageDataset/2/500.png
#  extracting: content/BreastCancerImageDataset/2/598.png
#  extracting: content/BreastCancerImageDataset/2/471.png
#  extracting: content/BreastCancerImageDataset/2/587.png
#  extracting: content/BreastCancerImageDataset/2/606.png
#  extracting: content/BreastCancerImageDataset/2/544.png
#  extracting: content/BreastCancerImageDataset/2/351.png
#  extracting: content/BreastCancerImageDataset/2/27.png
#  extracting: content/BreastCancerImageDataset/2/631.png
#  extracting: content/BreastCancerImageDataset/2/567.png
#  extracting: content/BreastCancerImageDataset/2/675.png
#  extracting: content/BreastCancerImageDataset/2/429.png
#  extracting: content/BreastCancerImageDataset/2/540.png
#  extracting: content/BreastCancerImageDataset/2/650.png
#  extracting: content/BreastCancerImageDataset/2/437.png
#  extracting: content/BreastCancerImageDataset/2/673.png
#  extracting: content/BreastCancerImageDataset/2/70.png
#  extracting: content/BreastCancerImageDataset/2/78.png
#  extracting: content/BreastCancerImageDataset/2/156.png
#  extracting: content/BreastCancerImageDataset/2/241.png
#  extracting: content/BreastCancerImageDataset/2/557.png
#  extracting: content/BreastCancerImageDataset/2/595.png
#  extracting: content/BreastCancerImageDataset/2/618.png
#  extracting: content/BreastCancerImageDataset/2/495.png
#  extracting: content/BreastCancerImageDataset/2/593.png
#  extracting: content/BreastCancerImageDataset/2/195.png
#  extracting: content/BreastCancerImageDataset/2/559.png
#  extracting: content/BreastCancerImageDataset/2/138.png
#  extracting: content/BreastCancerImageDataset/2/372.png
#  extracting: content/BreastCancerImageDataset/2/178.png
#   inflating: content/BreastCancerImageDataset/2/311.png
#  extracting: content/BreastCancerImageDataset/2/426.png
#   inflating: content/BreastCancerImageDataset/2/684.png
#   inflating: content/BreastCancerImageDataset/2/343.png
#  extracting: content/BreastCancerImageDataset/2/558.png
#  extracting: content/BreastCancerImageDataset/2/321.png
#  extracting: content/BreastCancerImageDataset/2/369.png
#  extracting: content/BreastCancerImageDataset/2/556.png
#  extracting: content/BreastCancerImageDataset/2/9.png
#  extracting: content/BreastCancerImageDataset/2/564.png
#  extracting: content/BreastCancerImageDataset/2/645.png
#   inflating: content/BreastCancerImageDataset/2/417.png
#  extracting: content/BreastCancerImageDataset/2/624.png
#  extracting: content/BreastCancerImageDataset/2/418.png
#   inflating: content/BreastCancerImageDataset/2/428.png
#  extracting: content/BreastCancerImageDataset/2/378.png
#  extracting: content/BreastCancerImageDataset/2/609.png
#  extracting: content/BreastCancerImageDataset/2/40.png
#  extracting: content/BreastCancerImageDataset/2/234.png
#  extracting: content/BreastCancerImageDataset/2/473.png
#  extracting: content/BreastCancerImageDataset/2/171.png
#  extracting: content/BreastCancerImageDataset/2/373.png
#  extracting: content/BreastCancerImageDataset/2/235.png
#  extracting: content/BreastCancerImageDataset/2/627.png
#  extracting: content/BreastCancerImageDataset/2/2.png
#  extracting: content/BreastCancerImageDataset/2/537.png
#   inflating: content/BreastCancerImageDataset/2/601.png
#  extracting: content/BreastCancerImageDataset/2/7.png
#  extracting: content/BreastCancerImageDataset/2/79.png
#  extracting: content/BreastCancerImageDataset/2/472.png
#   inflating: content/BreastCancerImageDataset/2/313.png
#  extracting: content/BreastCancerImageDataset/2/616.png
#  extracting: content/BreastCancerImageDataset/2/625.png
#  extracting: content/BreastCancerImageDataset/2/539.png
#  extracting: content/BreastCancerImageDataset/2/542.png
#  extracting: content/BreastCancerImageDataset/2/280.png
#  extracting: content/BreastCancerImageDataset/2/135.png
#  extracting: content/BreastCancerImageDataset/2/141.png
#   inflating: content/BreastCancerImageDataset/2/623.png
#  extracting: content/BreastCancerImageDataset/2/463.png
#   inflating: content/BreastCancerImageDataset/2/516.png
#  extracting: content/BreastCancerImageDataset/2/362.png
#    creating: content/BreastCancerImageDataset/4/
#  extracting: content/BreastCancerImageDataset/4/25.png
#  extracting: content/BreastCancerImageDataset/4/174.png
#  extracting: content/BreastCancerImageDataset/4/60.png
#  extracting: content/BreastCancerImageDataset/4/305.png
#  extracting: content/BreastCancerImageDataset/4/104.png
#  extracting: content/BreastCancerImageDataset/4/56.png
#  extracting: content/BreastCancerImageDataset/4/592.png
#  extracting: content/BreastCancerImageDataset/4/159.png
#  extracting: content/BreastCancerImageDataset/4/63.png
#  extracting: content/BreastCancerImageDataset/4/38.png
#  extracting: content/BreastCancerImageDataset/4/279.png
#  extracting: content/BreastCancerImageDataset/4/246.png
#  extracting: content/BreastCancerImageDataset/4/100.png
#  extracting: content/BreastCancerImageDataset/4/565.png
#  extracting: content/BreastCancerImageDataset/4/668.png
#  extracting: content/BreastCancerImageDataset/4/267.png
#  extracting: content/BreastCancerImageDataset/4/317.png
#  extracting: content/BreastCancerImageDataset/4/270.png
#  extracting: content/BreastCancerImageDataset/4/113.png
#  extracting: content/BreastCancerImageDataset/4/211.png
#  extracting: content/BreastCancerImageDataset/4/111.png
#  extracting: content/BreastCancerImageDataset/4/333.png
#  extracting: content/BreastCancerImageDataset/4/177.png
#  extracting: content/BreastCancerImageDataset/4/522.png
#  extracting: content/BreastCancerImageDataset/4/336.png
#  extracting: content/BreastCancerImageDataset/4/109.png
#  extracting: content/BreastCancerImageDataset/4/264.png
#  extracting: content/BreastCancerImageDataset/4/568.png
#  extracting: content/BreastCancerImageDataset/4/302.png
#  extracting: content/BreastCancerImageDataset/4/455.png
#  extracting: content/BreastCancerImageDataset/4/489.png
#  extracting: content/BreastCancerImageDataset/4/605.png
#  extracting: content/BreastCancerImageDataset/4/272.png
#  extracting: content/BreastCancerImageDataset/4/99.png
#  extracting: content/BreastCancerImageDataset/4/610.png
#  extracting: content/BreastCancerImageDataset/4/519.png
#  extracting: content/BreastCancerImageDataset/4/221.png
#  extracting: content/BreastCancerImageDataset/4/58.png
#  extracting: content/BreastCancerImageDataset/4/326.png
#  extracting: content/BreastCancerImageDataset/4/436.png
#  extracting: content/BreastCancerImageDataset/4/32.png
#  extracting: content/BreastCancerImageDataset/4/588.png
#  extracting: content/BreastCancerImageDataset/4/366.png
#  extracting: content/BreastCancerImageDataset/4/282.png
#  extracting: content/BreastCancerImageDataset/4/466.png
#  extracting: content/BreastCancerImageDataset/4/569.png
#  extracting: content/BreastCancerImageDataset/4/549.png
#  extracting: content/BreastCancerImageDataset/4/239.png
#  extracting: content/BreastCancerImageDataset/4/349.png
#  extracting: content/BreastCancerImageDataset/4/514.png
#  extracting: content/BreastCancerImageDataset/4/68.png
#  extracting: content/BreastCancerImageDataset/4/421.png
#  extracting: content/BreastCancerImageDataset/4/570.png
#  extracting: content/BreastCancerImageDataset/4/359.png
#  extracting: content/BreastCancerImageDataset/4/73.png
#  extracting: content/BreastCancerImageDataset/4/74.png
#  extracting: content/BreastCancerImageDataset/4/229.png
#  extracting: content/BreastCancerImageDataset/4/101.png
#  extracting: content/BreastCancerImageDataset/4/633.png
#  extracting: content/BreastCancerImageDataset/4/636.png
#  extracting: content/BreastCancerImageDataset/4/626.png
#  extracting: content/BreastCancerImageDataset/4/304.png
#  extracting: content/BreastCancerImageDataset/4/132.png
#  extracting: content/BreastCancerImageDataset/4/586.png
#  extracting: content/BreastCancerImageDataset/4/483.png
#  extracting: content/BreastCancerImageDataset/4/506.png
#  extracting: content/BreastCancerImageDataset/4/391.png
#  extracting: content/BreastCancerImageDataset/4/54.png
#  extracting: content/BreastCancerImageDataset/4/183.png
#  extracting: content/BreastCancerImageDataset/4/456.png
#  extracting: content/BreastCancerImageDataset/4/128.png
#  extracting: content/BreastCancerImageDataset/4/46.png
#  extracting: content/BreastCancerImageDataset/4/42.png
#  extracting: content/BreastCancerImageDataset/4/222.png
#  extracting: content/BreastCancerImageDataset/4/493.png
#  extracting: content/BreastCancerImageDataset/4/361.png
#  extracting: content/BreastCancerImageDataset/4/323.png
#  extracting: content/BreastCancerImageDataset/4/648.png
#  extracting: content/BreastCancerImageDataset/4/227.png
#  extracting: content/BreastCancerImageDataset/4/594.png
#  extracting: content/BreastCancerImageDataset/4/457.png
#  extracting: content/BreastCancerImageDataset/4/124.png
#  extracting: content/BreastCancerImageDataset/4/284.png
#  extracting: content/BreastCancerImageDataset/4/453.png
#  extracting: content/BreastCancerImageDataset/4/293.png
#  extracting: content/BreastCancerImageDataset/4/400.png
#  extracting: content/BreastCancerImageDataset/4/160.png
#  extracting: content/BreastCancerImageDataset/4/261.png
#  extracting: content/BreastCancerImageDataset/4/320.png
#  extracting: content/BreastCancerImageDataset/4/425.png
#  extracting: content/BreastCancerImageDataset/4/49.png
#  extracting: content/BreastCancerImageDataset/4/18.png
#  extracting: content/BreastCancerImageDataset/4/357.png
#  extracting: content/BreastCancerImageDataset/4/103.png
#  extracting: content/BreastCancerImageDataset/4/591.png
#  extracting: content/BreastCancerImageDataset/4/87.png
#  extracting: content/BreastCancerImageDataset/4/353.png
#  extracting: content/BreastCancerImageDataset/4/142.png
#  extracting: content/BreastCancerImageDataset/4/106.png
#  extracting: content/BreastCancerImageDataset/4/590.png
#  extracting: content/BreastCancerImageDataset/4/416.png
#  extracting: content/BreastCancerImageDataset/4/206.png
#  extracting: content/BreastCancerImageDataset/4/467.png
#  extracting: content/BreastCancerImageDataset/4/151.png
#  extracting: content/BreastCancerImageDataset/4/173.png
#  extracting: content/BreastCancerImageDataset/4/112.png
#  extracting: content/BreastCancerImageDataset/4/299.png
#  extracting: content/BreastCancerImageDataset/4/15.png
#  extracting: content/BreastCancerImageDataset/4/515.png
#  extracting: content/BreastCancerImageDataset/4/57.png
#  extracting: content/BreastCancerImageDataset/4/581.png
#  extracting: content/BreastCancerImageDataset/4/312.png
#  extracting: content/BreastCancerImageDataset/4/681.png
#  extracting: content/BreastCancerImageDataset/4/190.png
#  extracting: content/BreastCancerImageDataset/4/55.png
#  extracting: content/BreastCancerImageDataset/4/334.png
#  extracting: content/BreastCancerImageDataset/4/330.png
#  extracting: content/BreastCancerImageDataset/4/283.png
#  extracting: content/BreastCancerImageDataset/4/188.png
#  extracting: content/BreastCancerImageDataset/4/696.png
#  extracting: content/BreastCancerImageDataset/4/226.png
#  extracting: content/BreastCancerImageDataset/4/187.png
#  extracting: content/BreastCancerImageDataset/4/669.png
#  extracting: content/BreastCancerImageDataset/4/479.png
#  extracting: content/BreastCancerImageDataset/4/414.png
#  extracting: content/BreastCancerImageDataset/4/84.png
#  extracting: content/BreastCancerImageDataset/4/117.png
#  extracting: content/BreastCancerImageDataset/4/53.png
#  extracting: content/BreastCancerImageDataset/4/262.png
#  extracting: content/BreastCancerImageDataset/4/122.png
#  extracting: content/BreastCancerImageDataset/4/295.png
#  extracting: content/BreastCancerImageDataset/4/316.png
#  extracting: content/BreastCancerImageDataset/4/215.png
#  extracting: content/BreastCancerImageDataset/4/152.png
#  extracting: content/BreastCancerImageDataset/4/39.png
#  extracting: content/BreastCancerImageDataset/4/339.png
#  extracting: content/BreastCancerImageDataset/4/691.png
#  extracting: content/BreastCancerImageDataset/4/289.png
#  extracting: content/BreastCancerImageDataset/4/286.png
#  extracting: content/BreastCancerImageDataset/4/214.png
#  extracting: content/BreastCancerImageDataset/4/224.png
#  extracting: content/BreastCancerImageDataset/4/680.png
#  extracting: content/BreastCancerImageDataset/4/254.png
#  extracting: content/BreastCancerImageDataset/4/36.png
#  extracting: content/BreastCancerImageDataset/4/465.png
#  extracting: content/BreastCancerImageDataset/4/697.png
#  extracting: content/BreastCancerImageDataset/4/435.png
#  extracting: content/BreastCancerImageDataset/4/149.png
#  extracting: content/BreastCancerImageDataset/4/300.png
#  extracting: content/BreastCancerImageDataset/4/44.png
#  extracting: content/BreastCancerImageDataset/4/412.png
#  extracting: content/BreastCancerImageDataset/4/367.png
#  extracting: content/BreastCancerImageDataset/4/85.png
#  extracting: content/BreastCancerImageDataset/4/440.png
#  extracting: content/BreastCancerImageDataset/4/179.png
#  extracting: content/BreastCancerImageDataset/4/530.png
#  extracting: content/BreastCancerImageDataset/4/20.png
#  extracting: content/BreastCancerImageDataset/4/253.png
#  extracting: content/BreastCancerImageDataset/4/260.png
#  extracting: content/BreastCancerImageDataset/4/231.png
#  extracting: content/BreastCancerImageDataset/4/126.png
#  extracting: content/BreastCancerImageDataset/4/546.png
#  extracting: content/BreastCancerImageDataset/4/344.png
#  extracting: content/BreastCancerImageDataset/4/67.png
#  extracting: content/BreastCancerImageDataset/4/603.png
#  extracting: content/BreastCancerImageDataset/4/658.png
#  extracting: content/BreastCancerImageDataset/4/356.png
#  extracting: content/BreastCancerImageDataset/4/329.png
#  extracting: content/BreastCancerImageDataset/4/98.png
#  extracting: content/BreastCancerImageDataset/4/273.png
#  extracting: content/BreastCancerImageDataset/4/184.png
#  extracting: content/BreastCancerImageDataset/4/105.png
#  extracting: content/BreastCancerImageDataset/4/268.png
#  extracting: content/BreastCancerImageDataset/4/155.png
#  extracting: content/BreastCancerImageDataset/4/427.png
#  extracting: content/BreastCancerImageDataset/4/582.png
#  extracting: content/BreastCancerImageDataset/4/200.png
#  extracting: content/BreastCancerImageDataset/4/230.png
#  extracting: content/BreastCancerImageDataset/4/698.png
#  extracting: content/BreastCancerImageDataset/4/41.png
#  extracting: content/BreastCancerImageDataset/4/51.png
#  extracting: content/BreastCancerImageDataset/4/238.png
#  extracting: content/BreastCancerImageDataset/4/43.png
#  extracting: content/BreastCancerImageDataset/4/167.png
#  extracting: content/BreastCancerImageDataset/4/360.png
#  extracting: content/BreastCancerImageDataset/4/292.png
#  extracting: content/BreastCancerImageDataset/4/205.png
#  extracting: content/BreastCancerImageDataset/4/482.png
#  extracting: content/BreastCancerImageDataset/4/237.png
#  extracting: content/BreastCancerImageDataset/4/71.png
#  extracting: content/BreastCancerImageDataset/4/175.png
#  extracting: content/BreastCancerImageDataset/4/611.png
#  extracting: content/BreastCancerImageDataset/4/59.png
#  extracting: content/BreastCancerImageDataset/4/266.png
#  extracting: content/BreastCancerImageDataset/4/612.png
#  extracting: content/BreastCancerImageDataset/4/251.png
#  extracting: content/BreastCancerImageDataset/4/236.png
#  extracting: content/BreastCancerImageDataset/4/123.png
#  extracting: content/BreastCancerImageDataset/4/223.png
#  extracting: content/BreastCancerImageDataset/4/574.png
#  extracting: content/BreastCancerImageDataset/4/488.png
#  extracting: content/BreastCancerImageDataset/4/247.png
#  extracting: content/BreastCancerImageDataset/4/604.png
#  extracting: content/BreastCancerImageDataset/4/218.png
#  extracting: content/BreastCancerImageDataset/4/386.png
#  extracting: content/BreastCancerImageDataset/4/107.png
#  extracting: content/BreastCancerImageDataset/4/381.png
#  extracting: content/BreastCancerImageDataset/4/255.png
#  extracting: content/BreastCancerImageDataset/4/62.png
#  extracting: content/BreastCancerImageDataset/4/186.png
#  extracting: content/BreastCancerImageDataset/4/5.png
#  extracting: content/BreastCancerImageDataset/4/263.png
#  extracting: content/BreastCancerImageDataset/4/487.png
#  extracting: content/BreastCancerImageDataset/4/523.png
#  extracting: content/BreastCancerImageDataset/4/308.png
#  extracting: content/BreastCancerImageDataset/4/670.png
#  extracting: content/BreastCancerImageDataset/4/491.png
#  extracting: content/BreastCancerImageDataset/4/210.png
#  extracting: content/BreastCancerImageDataset/4/50.png
#  extracting: content/BreastCancerImageDataset/4/191.png
#  extracting: content/BreastCancerImageDataset/4/348.png
#  extracting: content/BreastCancerImageDataset/4/12.png
#  extracting: content/BreastCancerImageDataset/4/213.png
#  extracting: content/BreastCancerImageDataset/4/23.png
#  extracting: content/BreastCancerImageDataset/4/358.png
#  extracting: content/BreastCancerImageDataset/4/146.png
#  extracting: content/BreastCancerImageDataset/4/21.png
#  extracting: content/BreastCancerImageDataset/4/340.png
#  extracting: content/BreastCancerImageDataset/4/328.png
#  extracting: content/BreastCancerImageDataset/4/285.png
#  extracting: content/BreastCancerImageDataset/4/571.png
#  extracting: content/BreastCancerImageDataset/4/52.png
#  extracting: content/BreastCancerImageDataset/4/86.png
#  extracting: content/BreastCancerImageDataset/4/14.png
#  extracting: content/BreastCancerImageDataset/4/201.png
#  extracting: content/BreastCancerImageDataset/4/65.png
#  extracting: content/BreastCancerImageDataset/4/233.png
#  extracting: content/BreastCancerImageDataset/4/288.png
#  extracting: content/BreastCancerImageDataset/4/608.png
#  extracting: content/BreastCancerImageDataset/4/449.png
#  extracting: content/BreastCancerImageDataset/4/166.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/BreastCancerImageDataset", output="/content/content/BreastCancerSplit", seed=1337, ratio=(.80,  .20), group_prefix=None) # default values
# Out:
# Copying files: 699 files [00:00, 8476.80 files/s]

# %%
os.listdir("/content/content/BreastCancerSplit")
# Out:
# ['train', 'val']

# %% [markdown]
# ##DataLoaders

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/BreastCancerSplit'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 558, 'val': 141}, ['2', '4'], device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ##Training, Testing and Evaluation

# %% [markdown]
# ###Resnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.1965 Acc: 0.9319
# val Loss: 0.0470 Acc: 0.9858
#
# Epoch 1/19
# ----------
# train Loss: 0.0708 Acc: 0.9803
# val Loss: 0.0567 Acc: 0.9858
#
# Epoch 2/19
# ----------
# train Loss: 0.0169 Acc: 0.9964
# val Loss: 0.0585 Acc: 0.9858
#
# Epoch 3/19
# ----------
# train Loss: 0.0083 Acc: 1.0000
# val Loss: 0.0614 Acc: 0.9858
#
# Epoch 4/19
# ----------
# train Loss: 0.0101 Acc: 0.9964
# val Loss: 0.0586 Acc: 0.9858
#
# Epoch 5/19
# ----------
# train Loss: 0.0097 Acc: 0.9964
# val Loss: 0.0615 Acc: 0.9858
#
# Epoch 6/19
# ----------
# train Loss: 0.0048 Acc: 0.9982
# val Loss: 0.0612 Acc: 0.9858
#
# Epoch 7/19
# ----------
# train Loss: 0.0029 Acc: 1.0000
# val Loss: 0.0678 Acc: 0.9858
#
# Epoch 8/19
# ----------
# train Loss: 0.0038 Acc: 1.0000
# val Loss: 0.0677 Acc: 0.9858
#
# Epoch 9/19
# ----------
# train Loss: 0.0063 Acc: 0.9982
# val Loss: 0.0656 Acc: 0.9858
#
# Epoch 10/19
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.0616 Acc: 0.9858
#
# Epoch 11/19
# ----------
# train Loss: 0.0037 Acc: 1.0000
# val Loss: 0.0628 Acc: 0.9858
#
# Epoch 12/19
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.0634 Acc: 0.9858
#
# Epoch 13/19
# ----------
# train Loss: 0.0080 Acc: 1.0000
# val Loss: 0.0645 Acc: 0.9858
#
# Epoch 14/19
# ----------
# train Loss: 0.0068 Acc: 1.0000
# val Loss: 0.0670 Acc: 0.9858
#
# Epoch 15/19
# ----------
# train Loss: 0.0048 Acc: 1.0000
# val Loss: 0.0616 Acc: 0.9858
#
# Epoch 16/19
# ----------
# train Loss: 0.0038 Acc: 1.0000
# val Loss: 0.0676 Acc: 0.9858
#
# Epoch 17/19
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.0641 Acc: 0.9858
#
# Epoch 18/19
# ----------
# train Loss: 0.0027 Acc: 1.0000
# val Loss: 0.0591 Acc: 0.9858
#
# Epoch 19/19
# ----------
# train Loss: 0.0033 Acc: 1.0000
# val Loss: 0.0577 Acc: 0.9858
#
# Training complete in 0m 39s
# Best val Acc: 0.985816

# %%
torch.save(model_ft, "BreastCancer_Resnet18.pth")
model_ft = torch.load("/content/BreastCancer_Resnet18.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(98.9130)
# Specificity:  tensor(97.9592)
# PPV:  tensor(98.9130)
# NPV:  tensor(97.9592)

# %% [markdown]
# ###Densenet

# %%
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.8441 Acc: 0.9247
# val Loss: 0.1801 Acc: 0.9716
#
# Epoch 1/19
# ----------
# train Loss: 0.1227 Acc: 0.9624
# val Loss: 0.0332 Acc: 0.9858
#
# Epoch 2/19
# ----------
# train Loss: 0.0461 Acc: 0.9839
# val Loss: 0.0096 Acc: 1.0000
#
# Epoch 3/19
# ----------
# train Loss: 0.0093 Acc: 1.0000
# val Loss: 0.0066 Acc: 1.0000
#
# Epoch 4/19
# ----------
# train Loss: 0.0080 Acc: 1.0000
# val Loss: 0.0061 Acc: 1.0000
#
# Epoch 5/19
# ----------
# train Loss: 0.0084 Acc: 1.0000
# val Loss: 0.0058 Acc: 1.0000
#
# Epoch 6/19
# ----------
# train Loss: 0.0086 Acc: 1.0000
# val Loss: 0.0055 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0396 Acc: 0.9982
# val Loss: 0.0059 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0060 Acc: 1.0000
# val Loss: 0.0059 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0087 Acc: 1.0000
# val Loss: 0.0052 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0068 Acc: 1.0000
# val Loss: 0.0060 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0090 Acc: 1.0000
# val Loss: 0.0055 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0080 Acc: 1.0000
# val Loss: 0.0054 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0096 Acc: 1.0000
# val Loss: 0.0054 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0135 Acc: 0.9982
# val Loss: 0.0056 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0089 Acc: 1.0000
# val Loss: 0.0049 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0085 Acc: 1.0000
# val Loss: 0.0057 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0089 Acc: 1.0000
# val Loss: 0.0061 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0079 Acc: 1.0000
# val Loss: 0.0055 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0073 Acc: 1.0000
# val Loss: 0.0052 Acc: 1.0000
#
# Training complete in 1m 48s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "BreastCancer_Densenet.pth")
model_ft = torch.load("/content/BreastCancer_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# ###Inception V1

# %%
model_ft = models.googlenet(pretrained=False)
model_ft.aux_logits = False 
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/googlenet.py:50: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   FutureWarning,

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 0.3302 Acc: 0.8943
# val Loss: 0.7491 Acc: 0.3475
#
# Epoch 1/19
# ----------
# train Loss: 0.1590 Acc: 0.9391
# val Loss: 0.1274 Acc: 0.9858
#
# Epoch 2/19
# ----------
# train Loss: 0.0558 Acc: 0.9875
# val Loss: 0.0036 Acc: 1.0000
#
# Epoch 3/19
# ----------
# train Loss: 0.0050 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 4/19
# ----------
# train Loss: 0.0017 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 5/19
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 6/19
# ----------
# train Loss: 0.0017 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0013 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0016 Acc: 1.0000
# val Loss: 0.0003 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0003 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Training complete in 0m 56s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "BreastCancer_Inception.pth")
model_ft = torch.load("/content/BreastCancer_Inception.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# # 4) Cleveland

# %%
# !gdown --id 1o7KhzZmFwQYGeLOm-eFnP3TkdE7t6U31
#For zip Dataset Folders
# !unzip /content/ClevelandImageDataset.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id
# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/ClevelandImageDataset", output="/content/content/ClevelandSplit", seed=1337, ratio=(.85,  .15), group_prefix=None) # default values
# Out:
# Copying files: 297 files [00:00, 10098.48 files/s]

# %%
os.listdir("/content/content/ClevelandSplit")
# Out:
# ['train', 'val']

# %% [markdown]
# ##DataLoaders

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/ClevelandSplit'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 252, 'val': 45}, ['0', '1'], device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ##Training, Testing and Evaluation

# %% [markdown]
# ###Resnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.3397 Acc: 0.8532
# val Loss: 0.0034 Acc: 1.0000
#
# Epoch 1/19
# ----------
# train Loss: 0.0014 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 2/19
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 3/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 4/19
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 5/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 6/19
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0017 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Training complete in 0m 24s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Cleveland_Resnet18.pth")
model_ft = torch.load("/content/Cleveland_Resnet18.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# ###Densenet

# %%
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 2.0035 Acc: 0.8016
# val Loss: 1.4815 Acc: 0.4667
#
# Epoch 1/19
# ----------
# train Loss: 0.0309 Acc: 1.0000
# val Loss: 0.0125 Acc: 1.0000
#
# Epoch 2/19
# ----------
# train Loss: 0.0124 Acc: 1.0000
# val Loss: 0.0036 Acc: 1.0000
#
# Epoch 3/19
# ----------
# train Loss: 0.0081 Acc: 1.0000
# val Loss: 0.0045 Acc: 1.0000
#
# Epoch 4/19
# ----------
# train Loss: 0.0056 Acc: 1.0000
# val Loss: 0.0048 Acc: 1.0000
#
# Epoch 5/19
# ----------
# train Loss: 0.0077 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 6/19
# ----------
# train Loss: 0.0074 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0061 Acc: 1.0000
# val Loss: 0.0047 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0082 Acc: 1.0000
# val Loss: 0.0045 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0069 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0094 Acc: 1.0000
# val Loss: 0.0044 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0101 Acc: 1.0000
# val Loss: 0.0044 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0072 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0099 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0102 Acc: 1.0000
# val Loss: 0.0045 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0095 Acc: 1.0000
# val Loss: 0.0043 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0071 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0082 Acc: 1.0000
# val Loss: 0.0045 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0083 Acc: 1.0000
# val Loss: 0.0046 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0085 Acc: 1.0000
# val Loss: 0.0045 Acc: 1.0000
#
# Training complete in 0m 55s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Cleveland_Densenet.pth")
model_ft = torch.load("/content/Cleveland_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# ###Inception V1

# %%
model_ft = models.googlenet(pretrained=True)
model_ft.aux_logits = False 
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 0.2352 Acc: 0.9008
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 1/19
# ----------
# train Loss: 0.0050 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 2/19
# ----------
# train Loss: 0.0012 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 3/19
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 4/19
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 5/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 6/19
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 7/19
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 8/19
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 9/19
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 10/19
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 11/19
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 12/19
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 13/19
# ----------
# train Loss: 0.0019 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 14/19
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 15/19
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 16/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 17/19
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 18/19
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 19/19
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Training complete in 0m 38s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Cleveland_Inception.pth")
model_ft = torch.load("/content/Cleveland_Inception.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# # 5) Diabetes

# %%
# !gdown --id 1fOhli9O8PIhfIIegrJvgRQdZ52xmocqM
#For zip Dataset Folders
# !unzip /content/DiabetesImageDataset.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id
#   inflating: content/DiabetesImageDataset/Positive/105.png
#   inflating: content/DiabetesImageDataset/Positive/159.png
#   inflating: content/DiabetesImageDataset/Positive/88.png
#   inflating: content/DiabetesImageDataset/Positive/368.png
#   inflating: content/DiabetesImageDataset/Positive/98.png
#   inflating: content/DiabetesImageDataset/Positive/124.png
#   inflating: content/DiabetesImageDataset/Positive/185.png
#   inflating: content/DiabetesImageDataset/Positive/43.png
#   inflating: content/DiabetesImageDataset/Positive/84.png
#   inflating: content/DiabetesImageDataset/Positive/437.png
#   inflating: content/DiabetesImageDataset/Positive/15.png
#   inflating: content/DiabetesImageDataset/Positive/364.png
#   inflating: content/DiabetesImageDataset/Positive/427.png
#   inflating: content/DiabetesImageDataset/Positive/141.png
#   inflating: content/DiabetesImageDataset/Positive/35.png
#   inflating: content/DiabetesImageDataset/Positive/454.png
#   inflating: content/DiabetesImageDataset/Positive/167.png
#   inflating: content/DiabetesImageDataset/Positive/420.png
#   inflating: content/DiabetesImageDataset/Positive/94.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/DiabetesImageDataset", output="/content/content/DiabetesSplit", seed=1337, ratio=(.80,  .20), group_prefix=None) # default values
# Out:
# Copying files: 520 files [00:00, 9566.75 files/s]

# %%
os.listdir("/content/content/DiabetesSplit")
# Out:
# ['train', 'val']

# %% [markdown]
# ## Data Loaders

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/DiabetesSplit'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 416, 'val': 104},
#  ['Negative', 'Positive'],
#  device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## Traning, Testing and Evaluation

# %% [markdown]
# ## Restnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.1151 Acc: 0.9399
# val Loss: 0.0157 Acc: 1.0000
#
# Epoch 1/4
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Training complete in 0m 8s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Diabetes_Resnet18.pth")
model_ft = torch.load("/content/Diabetes_Resnet18.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# ## Densenet

# %%
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 1.1361 Acc: 0.9087
# val Loss: 0.2454 Acc: 0.9423
#
# Epoch 1/4
# ----------
# train Loss: 0.0103 Acc: 1.0000
# val Loss: 0.0049 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0044 Acc: 1.0000
# val Loss: 0.0015 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.0014 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0063 Acc: 1.0000
# val Loss: 0.0015 Acc: 1.0000
#
# Training complete in 0m 21s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Diabetes_Densenet.pth")
model_ft = torch.load("/content/Diabetes_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# ## Inception V1

# %%
model_ft = models.googlenet(pretrained=True)
model_ft.aux_logits = False 
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=15)
# Out:
# Epoch 0/14
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 0.1528 Acc: 0.9303
# val Loss: 0.0017 Acc: 1.0000
#
# Epoch 1/14
# ----------
# train Loss: 0.0069 Acc: 1.0000
# val Loss: 0.0003 Acc: 1.0000
#
# Epoch 2/14
# ----------
# train Loss: 0.0807 Acc: 0.9736
# val Loss: 3.0533 Acc: 0.3846
#
# Epoch 3/14
# ----------
# train Loss: 0.0034 Acc: 1.0000
# val Loss: 0.0004 Acc: 1.0000
#
# Epoch 4/14
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 5/14
# ----------
# train Loss: 0.0024 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 6/14
# ----------
# train Loss: 0.0023 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 7/14
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 8/14
# ----------
# train Loss: 0.0036 Acc: 1.0000
# val Loss: 0.0003 Acc: 1.0000
#
# Epoch 9/14
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 10/14
# ----------
# train Loss: 0.0019 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 11/14
# ----------
# train Loss: 0.0015 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 12/14
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 13/14
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 14/14
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Training complete in 0m 33s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Diabetes_Inception.pth")
model_ft = torch.load("/content/Diabetes_Inception.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# # 6) Adult Dataset

# %%
# !gdown --id 1XyLaAX8veW-Y27tBm_d9PVGbo2yF6dTj
#For zip Dataset Folders
# !unzip /content/AdultImageDataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating
#   inflating: content/AdultImageDataset/ <=50K/30019.png
#   inflating: content/AdultImageDataset/ <=50K/11665.png
#   inflating: content/AdultImageDataset/ <=50K/30625.png
#   inflating: content/AdultImageDataset/ <=50K/2125.png
#   inflating: content/AdultImageDataset/ <=50K/1703.png
#   inflating: content/AdultImageDataset/ <=50K/21238.png
#   inflating: content/AdultImageDataset/ <=50K/209.png
#   inflating: content/AdultImageDataset/ <=50K/2350.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/AdultImageDataset", output="/content/content/AdultSplit", seed=1337, ratio=(.90,  .10), group_prefix=None) # default values
# Out:
# Copying files: 48842 files [00:09, 5363.82 files/s]

# %%
os.listdir("/content/content/AdultSplit")
# Out:
# ['train', 'val']

# %% [markdown]
# ##DataLoaders

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/AdultSplit/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 43957, 'val': 4885},
#  [' <=50K', ' >50K'],
#  device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ##Resnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
#optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.0392 Acc: 0.9896
# val Loss: 0.0010 Acc: 1.0000
#
# Epoch 1/4
# ----------
# train Loss: 0.0022 Acc: 0.9999
# val Loss: 0.0004 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0003 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Training complete in 7m 32s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Adult_Resnet18.pth")
model_ft = torch.load("/content/Adult_Resnet18.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# ##Densenet

# %%
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.0120 Acc: 0.9992
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 1/4
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Training complete in 29m 24s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Adult_Densenet.pth")
model_ft = torch.load("/content/Adult_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# ##Inception V1

# %%
model_ft = models.googlenet(pretrained=True)
model_ft.aux_logits = False 
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=5, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 0.0027 Acc: 0.9992
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 1/4
# ----------
# train Loss: 0.0029 Acc: 0.9993
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0000 Acc: 1.0000
#
# Training complete in 12m 36s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Adult_Inception.pth")
model_ft = torch.load("/content/Adult_Inception.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %% [markdown]
# 7) Titanic Dataset

# %%
# !gdown --id 1dm5qVnbWSmwfSsOoFbTHs7oBGD2zwpxr
#For zip Dataset Folders
# !unzip /content/TitanicImageDataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/TitanicImageDataset/True/3696.png
#   inflating: content/TitanicImageDataset/True/4180.png
#   inflating: content/TitanicImageDataset/True/1116.png
#   inflating: content/TitanicImageDataset/True/314.png
#   inflating: content/TitanicImageDataset/True/2435.png
#   inflating: content/TitanicImageDataset/True/3181.png
#   inflating: content/TitanicImageDataset/True/4279.png
#   inflating: content/TitanicImageDataset/True/4413.png
#   inflating: content/TitanicImageDataset/True/2159.png
#   inflating: content/TitanicImageDataset/True/5035.png
#   inflating: content/TitanicImageDataset/True/3024.png
#   inflating: content/TitanicImageDataset/True/6188.png
#   inflating: content/TitanicImageDataset/True/5920.png
#   inflating: content/TitanicImageDataset/True/7857.png
#   inflating: content/TitanicImageDataset/True/6159.png
#   inflating: content/TitanicImageDataset/True/5266.png
#   inflating: content/TitanicImageDataset/True/7205.png
#   inflating: content/TitanicImageDataset/True/5206.png
#   inflating: content/TitanicImageDataset/True/2916.png
#   inflating: content/TitanicImageDataset/True/2251.png
#   inflating: content/TitanicImageDataset/True/2170.png
#   inflating: content/TitanicImageDataset/True/473.png
#   inflating: content/TitanicImageDataset/True/4829.png
#   inflating: content/TitanicImageDataset/True/6875.png
#   inflating: content/TitanicImageDataset/True/4247.png
#   inflating: content/TitanicImageDataset/True/6937.png
#   inflating: content/TitanicImageDataset/True/7704.png
#   inflating: content/TitanicImageDataset/True/7652.png
#   inflating: content/TitanicImageDataset/True/7149.png
#   inflating: content/TitanicImageDataset/True/4170.png
#   inflating: content/TitanicImageDataset/True/3961.png
#   inflating: content/TitanicImageDataset/True/7141.png
#   inflating: content/TitanicImageDataset/True/2088.png
#   inflating: content/TitanicImageDataset/True/1454.png
#   inflating: content/TitanicImageDataset/True/1904.png
#   inflating: content/TitanicImageDataset/True/3962.png
#   inflating: content/TitanicImageDataset/True/300.png
#   inflating: content/TitanicImageDataset/True/5165.png
#   inflating: content/TitanicImageDataset/True/7263.png
#   inflating: content/TitanicImageDataset/True/3767.png
#   inflating: content/TitanicImageDataset/True/6946.png
#   inflating: content/TitanicImageDataset/True/7517.png
#   inflating: content/TitanicImageDataset/True/6935.png
#   inflating: content/TitanicImageDataset/True/5137.png
#   inflating: content/TitanicImageDataset/True/7437.png
#   inflating: content/TitanicImageDataset/True/5613.png
#   inflating: content/TitanicImageDataset/True/5195.png
#   inflating: content/TitanicImageDataset/True/6738.png
#   inflating: content/TitanicImageDataset/True/5836.png
#   inflating: content/TitanicImageDataset/True/7947.png
#   inflating: content/TitanicImageDataset/True/7592.png
#   inflating: content/TitanicImageDataset/True/5395.png
#   inflating: content/TitanicImageDataset/True/5567.png
#   inflating: content/TitanicImageDataset/True/7431.png
#   inflating: content/TitanicImageDataset/True/6682.png
#   inflating: content/TitanicImageDataset/True/8220.png
#   inflating: content/TitanicImageDataset/True/3724.png
#   inflating: content/TitanicImageDataset/True/3667.png
#   inflating: content/TitanicImageDataset/True/7994.png
#   inflating: content/TitanicImageDataset/True/8332.png
#   inflating: content/TitanicImageDataset/True/1412.png
#   inflating: content/TitanicImageDataset/True/4372.png
#   inflating: content/TitanicImageDataset/True/7278.png
#   inflating: content/TitanicImageDataset/True/5040.png
#   inflating: content/TitanicImageDataset/True/8096.png
#   inflating: content/TitanicImageDataset/True/6559.png
#   inflating: content/TitanicImageDataset/True/3388.png
#   inflating: content/TitanicImageDataset/True/8076.png
#   inflating: content/TitanicImageDataset/True/4590.png
#   inflating: content/TitanicImageDataset/True/1121.png
#   inflating: content/TitanicImageDataset/True/1675.png
#   inflating: content/TitanicImageDataset/True/3112.png
#   inflating: content/TitanicImageDataset/True/5455.png
#   inflating: content/TitanicImageDataset/True/4060.png
#   inflating: content/TitanicImageDataset/True/5752.png
#   inflating: content/TitanicImageDataset/True/5546.png
#   inflating: content/TitanicImageDataset/True/7793.png
#   inflating: content/TitanicImageDataset/True/6117.png
#   inflating: content/TitanicImageDataset/True/6448.png
#   inflating: content/TitanicImageDataset/True/5384.png
#   inflating: content/TitanicImageDataset/True/4913.png
#   inflating: content/TitanicImageDataset/True/2536.png
#   inflating: content/TitanicImageDataset/True/1362.png
#   inflating: content/TitanicImageDataset/True/8224.png
#   inflating: content/TitanicImageDataset/True/4163.png
#   inflating: content/TitanicImageDataset/True/2630.png
#   inflating: content/TitanicImageDataset/True/3407.png
#   inflating: content/TitanicImageDataset/True/6710.png
#   inflating: content/TitanicImageDataset/True/2840.png
#   inflating: content/TitanicImageDataset/True/4598.png
#   inflating: content/TitanicImageDataset/True/6508.png
#   inflating: content/TitanicImageDataset/True/8544.png
#   inflating: content/TitanicImageDataset/True/4230.png
#   inflating: content/TitanicImageDataset/True/2720.png
#   inflating: content/TitanicImageDataset/True/3774.png
#   inflating: content/TitanicImageDataset/True/1159.png
#   inflating: content/TitanicImageDataset/True/1301.png
#   inflating: content/TitanicImageDataset/True/6349.png
#   inflating: content/TitanicImageDataset/True/2655.png
#   inflating: content/TitanicImageDataset/True/4518.png
#   inflating: content/TitanicImageDataset/True/7115.png
#   inflating: content/TitanicImageDataset/True/8499.png
#   inflating: content/TitanicImageDataset/True/4866.png
#   inflating: content/TitanicImageDataset/True/3042.png
#   inflating: content/TitanicImageDataset/True/7384.png
#   inflating: content/TitanicImageDataset/True/7475.png
#   inflating: content/TitanicImageDataset/True/5098.png
#   inflating: content/TitanicImageDataset/True/1505.png
#   inflating: content/TitanicImageDataset/True/4854.png
#   inflating: content/TitanicImageDataset/True/2592.png
#   inflating: content/TitanicImageDataset/True/4912.png
#   inflating: content/TitanicImageDataset/True/7458.png
#   inflating: content/TitanicImageDataset/True/5446.png
#   inflating: content/TitanicImageDataset/True/5133.png
#   inflating: content/TitanicImageDataset/True/4051.png
#   inflating: content/TitanicImageDataset/True/4409.png
#   inflating: content/TitanicImageDataset/True/7377.png
#   inflating: content/TitanicImageDataset/True/8328.png
#   inflating: content/TitanicImageDataset/True/4014.png
#   inflating: content/TitanicImageDataset/True/5004.png
#   inflating: content/TitanicImageDataset/True/7535.png
#   inflating: content/TitanicImageDataset/True/5520.png
#   inflating: content/TitanicImageDataset/True/2263.png
#   inflating: content/TitanicImageDataset/True/8256.png
#   inflating: content/TitanicImageDataset/True/3160.png
#   inflating: content/TitanicImageDataset/True/4558.png
#   inflating: content/TitanicImageDataset/True/245.png
#   inflating: content/TitanicImageDataset/True/5532.png
#   inflating: content/TitanicImageDataset/True/1114.png
#   inflating: content/TitanicImageDataset/True/7634.png
#   inflating: content/TitanicImageDataset/True/4895.png
#   inflating: content/TitanicImageDataset/True/5778.png
#   inflating: content/TitanicImageDataset/True/2012.png
#   inflating: content/TitanicImageDataset/True/7730.png
#   inflating: content/TitanicImageDataset/True/416.png
#   inflating: content/TitanicImageDataset/True/1139.png
#   inflating: content/TitanicImageDataset/True/2313.png
#   inflating: content/TitanicImageDataset/True/3917.png
#   inflating: content/TitanicImageDataset/True/6338.png
#   inflating: content/TitanicImageDataset/True/8310.png
#   inflating: content/TitanicImageDataset/True/8511.png
#   inflating: content/TitanicImageDataset/True/3038.png
#   inflating: content/TitanicImageDataset/True/115.png
#   inflating: content/TitanicImageDataset/True/6395.png
#   inflating: content/TitanicImageDataset/True/1.png
#   inflating: content/TitanicImageDataset/True/41.png
#   inflating: content/TitanicImageDataset/True/6137.png
#   inflating: content/TitanicImageDataset/True/7049.png
#   inflating: content/TitanicImageDataset/True/980.png
#   inflating: content/TitanicImageDataset/True/4420.png
#   inflating: content/TitanicImageDataset/True/6711.png
#   inflating: content/TitanicImageDataset/True/2247.png
#   inflating: content/TitanicImageDataset/True/524.png
#   inflating: content/TitanicImageDataset/True/6995.png
#   inflating: content/TitanicImageDataset/True/3059.png
#   inflating: content/TitanicImageDataset/True/1882.png
#   inflating: content/TitanicImageDataset/True/8043.png
#   inflating: content/TitanicImageDataset/True/7255.png
#   inflating: content/TitanicImageDataset/True/1889.png
#   inflating: content/TitanicImageDataset/True/711.png
#   inflating: content/TitanicImageDataset/True/2867.png
#   inflating: content/TitanicImageDataset/True/4494.png
#   inflating: content/TitanicImageDataset/True/8494.png
#   inflating: content/TitanicImageDataset/True/5600.png
#   inflating: content/TitanicImageDataset/True/3017.png
#   inflating: content/TitanicImageDataset/True/6663.png
#   inflating: content/TitanicImageDataset/True/1954.png
#   inflating: content/TitanicImageDataset/True/6545.png
#   inflating: content/TitanicImageDataset/True/7283.png
#   inflating: content/TitanicImageDataset/True/2181.png
#   inflating: content/TitanicImageDataset/True/2971.png
#   inflating: content/TitanicImageDataset/True/6581.png
#   inflating: content/TitanicImageDataset/True/3315.png
#   inflating: content/TitanicImageDataset/True/2424.png
#   inflating: content/TitanicImageDataset/True/4361.png
#   inflating: content/TitanicImageDataset/True/487.png
#   inflating: content/TitanicImageDataset/True/7123.png
#   inflating: content/TitanicImageDataset/True/4914.png
#   inflating: content/TitanicImageDataset/True/4177.png
#   inflating: content/TitanicImageDataset/True/3979.png
#   inflating: content/TitanicImageDataset/True/7588.png
#   inflating: content/TitanicImageDataset/True/412.png
#   inflating: content/TitanicImageDataset/True/3296.png
#   inflating: content/TitanicImageDataset/True/306.png
#   inflating: content/TitanicImageDataset/True/8386.png
#   inflating: content/TitanicImageDataset/True/1961.png
#   inflating: content/TitanicImageDataset/True/5477.png
#   inflating: content/TitanicImageDataset/True/260.png
#   inflating: content/TitanicImageDataset/True/4400.png
#   inflating: content/TitanicImageDataset/True/4532.png
#   inflating: content/TitanicImageDataset/True/994.png
#   inflating: content/TitanicImageDataset/True/5939.png
#   inflating: content/TitanicImageDataset/True/6620.png
#   inflating: content/TitanicImageDataset/True/7901.png
#   inflating: content/TitanicImageDataset/True/2561.png
#   inflating: content/TitanicImageDataset/True/3377.png
#   inflating: content/TitanicImageDataset/True/5895.png
#   inflating: content/TitanicImageDataset/True/1067.png
#   inflating: content/TitanicImageDataset/True/6039.png
#   inflating: content/TitanicImageDataset/True/3212.png
#   inflating: content/TitanicImageDataset/True/679.png
#   inflating: content/TitanicImageDataset/True/6618.png
#   inflating: content/TitanicImageDataset/True/8268.png
#   inflating: content/TitanicImageDataset/True/5073.png
#   inflating: content/TitanicImageDataset/True/918.png
#   inflating: content/TitanicImageDataset/True/1496.png
#   inflating: content/TitanicImageDataset/True/8176.png
#   inflating: content/TitanicImageDataset/True/5638.png
#   inflating: content/TitanicImageDataset/True/1066.png
#   inflating: content/TitanicImageDataset/True/1149.png
#   inflating: content/TitanicImageDataset/True/3449.png
#   inflating: content/TitanicImageDataset/True/5670.png
#   inflating: content/TitanicImageDataset/True/6667.png
#   inflating: content/TitanicImageDataset/True/6526.png
#   inflating: content/TitanicImageDataset/True/8627.png
#   inflating: content/TitanicImageDataset/True/4773.png
#   inflating: content/TitanicImageDataset/True/4628.png
#   inflating: content/TitanicImageDataset/True/5353.png
#   inflating: content/TitanicImageDataset/True/7805.png
#   inflating: content/TitanicImageDataset/True/7979.png
#   inflating: content/TitanicImageDataset/True/970.png
#   inflating: content/TitanicImageDataset/True/1848.png
#   inflating: content/TitanicImageDataset/True/2162.png
#   inflating: content/TitanicImageDataset/True/8177.png
#   inflating: content/TitanicImageDataset/True/1379.png
#   inflating: content/TitanicImageDataset/True/6993.png
#   inflating: content/TitanicImageDataset/True/1403.png
#   inflating: content/TitanicImageDataset/True/5747.png
#   inflating: content/TitanicImageDataset/True/5156.png
#   inflating: content/TitanicImageDataset/True/4241.png
#   inflating: content/TitanicImageDataset/True/3389.png
#   inflating: content/TitanicImageDataset/True/3650.png
#   inflating: content/TitanicImageDataset/True/1831.png
#   inflating: content/TitanicImageDataset/True/3617.png
#   inflating: content/TitanicImageDataset/True/5086.png
#   inflating: content/TitanicImageDataset/True/6980.png
#   inflating: content/TitanicImageDataset/True/4967.png
#   inflating: content/TitanicImageDataset/True/4548.png
#   inflating: content/TitanicImageDataset/True/4903.png
#   inflating: content/TitanicImageDataset/True/1198.png
#   inflating: content/TitanicImageDataset/True/5361.png
#   inflating: content/TitanicImageDataset/True/5274.png
#   inflating: content/TitanicImageDataset/True/6330.png
#   inflating: content/TitanicImageDataset/True/6104.png
#   inflating: content/TitanicImageDataset/True/2343.png
#   inflating: content/TitanicImageDataset/True/7169.png
#   inflating: content/TitanicImageDataset/True/1967.png
#   inflating: content/TitanicImageDataset/True/5695.png
#   inflating: content/TitanicImageDataset/True/1491.png
#   inflating: content/TitanicImageDataset/True/3415.png
#   inflating: content/TitanicImageDataset/True/2430.png
#   inflating: content/TitanicImageDataset/True/1571.png
#   inflating: content/TitanicImageDataset/True/257.png
#   inflating: content/TitanicImageDataset/True/6406.png
#   inflating: content/TitanicImageDataset/True/8303.png
#   inflating: content/TitanicImageDataset/True/6501.png
#   inflating: content/TitanicImageDataset/True/187.png
#   inflating: content/TitanicImageDataset/True/4664.png
#   inflating: content/TitanicImageDataset/True/1674.png
#   inflating: content/TitanicImageDataset/True/2974.png
#   inflating: content/TitanicImageDataset/True/2910.png
#   inflating: content/TitanicImageDataset/True/5488.png
#   inflating: content/TitanicImageDataset/True/1371.png
#   inflating: content/TitanicImageDataset/True/3534.png
#   inflating: content/TitanicImageDataset/True/1494.png
#   inflating: content/TitanicImageDataset/True/6084.png
#   inflating: content/TitanicImageDataset/True/3052.png
#   inflating: content/TitanicImageDataset/True/8110.png
#   inflating: content/TitanicImageDataset/True/6228.png
#   inflating: content/TitanicImageDataset/True/3680.png
#   inflating: content/TitanicImageDataset/True/5574.png
#   inflating: content/TitanicImageDataset/True/4018.png
#   inflating: content/TitanicImageDataset/True/2853.png
#   inflating: content/TitanicImageDataset/True/4983.png
#   inflating: content/TitanicImageDataset/True/7034.png
#   inflating: content/TitanicImageDataset/True/7163.png
#   inflating: content/TitanicImageDataset/True/6976.png
#   inflating: content/TitanicImageDataset/True/4953.png
#   inflating: content/TitanicImageDataset/True/5189.png
#   inflating: content/TitanicImageDataset/True/1103.png
#   inflating: content/TitanicImageDataset/True/1732.png
#   inflating: content/TitanicImageDataset/True/543.png
#   inflating: content/TitanicImageDataset/True/4111.png
#   inflating: content/TitanicImageDataset/True/6441.png
#   inflating: content/TitanicImageDataset/True/2450.png
#   inflating: content/TitanicImageDataset/True/4700.png
#   inflating: content/TitanicImageDataset/True/1063.png
#   inflating: content/TitanicImageDataset/True/8570.png
#   inflating: content/TitanicImageDataset/True/4139.png
#   inflating: content/TitanicImageDataset/True/3075.png
#   inflating: content/TitanicImageDataset/True/5686.png
#   inflating: content/TitanicImageDataset/True/3727.png
#   inflating: content/TitanicImageDataset/True/7918.png
#   inflating: content/TitanicImageDataset/True/1721.png
#   inflating: content/TitanicImageDataset/True/7523.png
#   inflating: content/TitanicImageDataset/True/619.png
#   inflating: content/TitanicImageDataset/True/557.png
#   inflating: content/TitanicImageDataset/True/2456.png
#   inflating: content/TitanicImageDataset/True/4147.png
#   inflating: content/TitanicImageDataset/True/4002.png
#   inflating: content/TitanicImageDataset/True/7643.png
#   inflating: content/TitanicImageDataset/True/988.png
#   inflating: content/TitanicImageDataset/True/5541.png
#   inflating: content/TitanicImageDataset/True/4920.png
#   inflating: content/TitanicImageDataset/True/7396.png
#   inflating: content/TitanicImageDataset/True/2150.png
#   inflating: content/TitanicImageDataset/True/759.png
#   inflating: content/TitanicImageDataset/True/3967.png
#   inflating: content/TitanicImageDataset/True/2943.png
#   inflating: content/TitanicImageDataset/True/1061.png
#   inflating: content/TitanicImageDataset/True/1948.png
#   inflating: content/TitanicImageDataset/True/8002.png
#   inflating: content/TitanicImageDataset/True/93.png
#   inflating: content/TitanicImageDataset/True/4998.png
#   inflating: content/TitanicImageDataset/True/976.png
#   inflating: content/TitanicImageDataset/True/1161.png
#   inflating: content/TitanicImageDataset/True/1641.png
#   inflating: content/TitanicImageDataset/True/6879.png
#   inflating: content/TitanicImageDataset/True/1147.png
#   inflating: content/TitanicImageDataset/True/3463.png
#   inflating: content/TitanicImageDataset/True/8107.png
#   inflating: content/TitanicImageDataset/True/3498.png
#   inflating: content/TitanicImageDataset/True/6589.png
#   inflating: content/TitanicImageDataset/True/6780.png
#   inflating: content/TitanicImageDataset/True/8362.png
#   inflating: content/TitanicImageDataset/True/2378.png
#   inflating: content/TitanicImageDataset/True/145.png
#   inflating: content/TitanicImageDataset/True/4703.png
#   inflating: content/TitanicImageDataset/True/3356.png
#   inflating: content/TitanicImageDataset/True/4937.png
#   inflating: content/TitanicImageDataset/True/1939.png
#   inflating: content/TitanicImageDataset/True/2969.png
#   inflating: content/TitanicImageDataset/True/6449.png
#   inflating: content/TitanicImageDataset/True/3357.png
#   inflating: content/TitanicImageDataset/True/4579.png
#   inflating: content/TitanicImageDataset/True/8358.png
#   inflating: content/TitanicImageDataset/True/8489.png
#   inflating: content/TitanicImageDataset/True/4918.png
#   inflating: content/TitanicImageDataset/True/7550.png
#   inflating: content/TitanicImageDataset/True/3429.png
#   inflating: content/TitanicImageDataset/True/4016.png
#   inflating: content/TitanicImageDataset/True/3731.png
#   inflating: content/TitanicImageDataset/True/1804.png
#   inflating: content/TitanicImageDataset/True/511.png
#   inflating: content/TitanicImageDataset/True/4621.png
#   inflating: content/TitanicImageDataset/True/4357.png
#   inflating: content/TitanicImageDataset/True/8341.png
#   inflating: content/TitanicImageDataset/True/6169.png
#   inflating: content/TitanicImageDataset/True/8197.png
#   inflating: content/TitanicImageDataset/True/3583.png
#   inflating: content/TitanicImageDataset/True/6964.png
#   inflating: content/TitanicImageDataset/True/35.png
#   inflating: content/TitanicImageDataset/True/4989.png
#   inflating: content/TitanicImageDataset/True/7692.png
#   inflating: content/TitanicImageDataset/True/4239.png
#   inflating: content/TitanicImageDataset/True/5616.png
#   inflating: content/TitanicImageDataset/True/7613.png
#   inflating: content/TitanicImageDataset/True/1250.png
#   inflating: content/TitanicImageDataset/True/4021.png
#   inflating: content/TitanicImageDataset/True/6225.png
#   inflating: content/TitanicImageDataset/True/3168.png
#   inflating: content/TitanicImageDataset/True/6089.png
#   inflating: content/TitanicImageDataset/True/5880.png
#   inflating: content/TitanicImageDataset/True/6371.png
#   inflating: content/TitanicImageDataset/True/4175.png
#   inflating: content/TitanicImageDataset/True/623.png
#   inflating: content/TitanicImageDataset/True/1031.png
#   inflating: content/TitanicImageDataset/True/8285.png
#   inflating: content/TitanicImageDataset/True/24.png
#   inflating: content/TitanicImageDataset/True/6279.png
#   inflating: content/TitanicImageDataset/True/4943.png
#   inflating: content/TitanicImageDataset/True/7740.png
#   inflating: content/TitanicImageDataset/True/4545.png
#   inflating: content/TitanicImageDataset/True/6471.png
#   inflating: content/TitanicImageDataset/True/1306.png
#   inflating: content/TitanicImageDataset/True/4042.png
#   inflating: content/TitanicImageDataset/True/7258.png
#   inflating: content/TitanicImageDataset/True/3969.png
#   inflating: content/TitanicImageDataset/True/682.png
#   inflating: content/TitanicImageDataset/True/8349.png
#   inflating: content/TitanicImageDataset/True/3584.png
#   inflating: content/TitanicImageDataset/True/5780.png
#   inflating: content/TitanicImageDataset/True/4534.png
#   inflating: content/TitanicImageDataset/True/6932.png
#   inflating: content/TitanicImageDataset/True/7756.png
#   inflating: content/TitanicImageDataset/True/3831.png
#   inflating: content/TitanicImageDataset/True/7537.png
#   inflating: content/TitanicImageDataset/True/536.png
#   inflating: content/TitanicImageDataset/True/5200.png
#   inflating: content/TitanicImageDataset/True/4291.png
#   inflating: content/TitanicImageDataset/True/3813.png
#   inflating: content/TitanicImageDataset/True/1918.png
#   inflating: content/TitanicImageDataset/True/5877.png
#   inflating: content/TitanicImageDataset/True/7706.png
#   inflating: content/TitanicImageDataset/True/2204.png
#   inflating: content/TitanicImageDataset/True/4131.png
#   inflating: content/TitanicImageDataset/True/5329.png
#   inflating: content/TitanicImageDataset/True/3887.png
#   inflating: content/TitanicImageDataset/True/7227.png
#   inflating: content/TitanicImageDataset/True/3602.png
#   inflating: content/TitanicImageDataset/True/2493.png
#   inflating: content/TitanicImageDataset/True/5696.png
#   inflating: content/TitanicImageDataset/True/5315.png
#   inflating: content/TitanicImageDataset/True/5425.png
#   inflating: content/TitanicImageDataset/True/6041.png
#   inflating: content/TitanicImageDataset/True/7268.png
#   inflating: content/TitanicImageDataset/True/427.png
#   inflating: content/TitanicImageDataset/True/2629.png
#   inflating: content/TitanicImageDataset/True/2178.png
#   inflating: content/TitanicImageDataset/True/7030.png
#   inflating: content/TitanicImageDataset/True/4421.png
#   inflating: content/TitanicImageDataset/True/3280.png
#   inflating: content/TitanicImageDataset/True/4916.png
#   inflating: content/TitanicImageDataset/True/7769.png
#   inflating: content/TitanicImageDataset/True/7477.png
#   inflating: content/TitanicImageDataset/True/195.png
#   inflating: content/TitanicImageDataset/True/5071.png
#   inflating: content/TitanicImageDataset/True/4733.png
#   inflating: content/TitanicImageDataset/True/5800.png
#   inflating: content/TitanicImageDataset/True/4448.png
#   inflating: content/TitanicImageDataset/True/4715.png
#   inflating: content/TitanicImageDataset/True/2985.png
#   inflating: content/TitanicImageDataset/True/1448.png
#   inflating: content/TitanicImageDataset/True/6804.png
#   inflating: content/TitanicImageDataset/True/6491.png
#   inflating: content/TitanicImageDataset/True/5333.png
#   inflating: content/TitanicImageDataset/True/6708.png
#   inflating: content/TitanicImageDataset/True/2024.png
#   inflating: content/TitanicImageDataset/True/2700.png
#   inflating: content/TitanicImageDataset/True/3295.png
#   inflating: content/TitanicImageDataset/True/3810.png
#   inflating: content/TitanicImageDataset/True/8024.png
#   inflating: content/TitanicImageDataset/True/3101.png
#   inflating: content/TitanicImageDataset/True/2355.png
#   inflating: content/TitanicImageDataset/True/5761.png
#   inflating: content/TitanicImageDataset/True/8277.png
#   inflating: content/TitanicImageDataset/True/3728.png
#   inflating: content/TitanicImageDataset/True/676.png
#   inflating: content/TitanicImageDataset/True/6383.png
#   inflating: content/TitanicImageDataset/True/2543.png
#   inflating: content/TitanicImageDataset/True/4500.png
#   inflating: content/TitanicImageDataset/True/1026.png
#   inflating: content/TitanicImageDataset/True/7308.png
#   inflating: content/TitanicImageDataset/True/6555.png
#   inflating: content/TitanicImageDataset/True/2777.png
#   inflating: content/TitanicImageDataset/True/7008.png
#   inflating: content/TitanicImageDataset/True/5604.png
#   inflating: content/TitanicImageDataset/True/8412.png
#   inflating: content/TitanicImageDataset/True/6818.png
#   inflating: content/TitanicImageDataset/True/2102.png
#   inflating: content/TitanicImageDataset/True/8560.png
#   inflating: content/TitanicImageDataset/True/7464.png
#   inflating: content/TitanicImageDataset/True/580.png
#   inflating: content/TitanicImageDataset/True/5136.png
#   inflating: content/TitanicImageDataset/True/1173.png
#   inflating: content/TitanicImageDataset/True/1282.png
#   inflating: content/TitanicImageDataset/True/5227.png
#   inflating: content/TitanicImageDataset/True/6267.png
#   inflating: content/TitanicImageDataset/True/5452.png
#   inflating: content/TitanicImageDataset/True/4212.png
#   inflating: content/TitanicImageDataset/True/4288.png
#   inflating: content/TitanicImageDataset/True/6004.png
#   inflating: content/TitanicImageDataset/True/380.png
#   inflating: content/TitanicImageDataset/True/4594.png
#   inflating: content/TitanicImageDataset/True/5102.png
#   inflating: content/TitanicImageDataset/True/6623.png
#   inflating: content/TitanicImageDataset/True/1840.png
#   inflating: content/TitanicImageDataset/True/8513.png
#   inflating: content/TitanicImageDataset/True/2679.png
#   inflating: content/TitanicImageDataset/True/939.png
#   inflating: content/TitanicImageDataset/True/601.png
#   inflating: content/TitanicImageDataset/True/3577.png
#   inflating: content/TitanicImageDataset/True/202.png
#   inflating: content/TitanicImageDataset/True/6236.png
#   inflating: content/TitanicImageDataset/True/5992.png
#   inflating: content/TitanicImageDataset/True/2328.png
#   inflating: content/TitanicImageDataset/True/7703.png
#   inflating: content/TitanicImageDataset/True/1518.png
#   inflating: content/TitanicImageDataset/True/3570.png
#   inflating: content/TitanicImageDataset/True/8046.png
#   inflating: content/TitanicImageDataset/True/5903.png
#   inflating: content/TitanicImageDataset/True/807.png
#   inflating: content/TitanicImageDataset/True/857.png
#   inflating: content/TitanicImageDataset/True/1076.png
#   inflating: content/TitanicImageDataset/True/6339.png
#   inflating: content/TitanicImageDataset/True/429.png
#   inflating: content/TitanicImageDataset/True/7644.png
#   inflating: content/TitanicImageDataset/True/5702.png
#   inflating: content/TitanicImageDataset/True/5023.png
#   inflating: content/TitanicImageDataset/True/71.png
#   inflating: content/TitanicImageDataset/True/993.png
#   inflating: content/TitanicImageDataset/True/3054.png
#   inflating: content/TitanicImageDataset/True/3654.png
#   inflating: content/TitanicImageDataset/True/474.png
#   inflating: content/TitanicImageDataset/True/2417.png
#   inflating: content/TitanicImageDataset/True/4299.png
#   inflating: content/TitanicImageDataset/True/2634.png
#   inflating: content/TitanicImageDataset/True/6411.png
#   inflating: content/TitanicImageDataset/True/6055.png
#   inflating: content/TitanicImageDataset/True/7296.png
#   inflating: content/TitanicImageDataset/True/2892.png
#   inflating: content/TitanicImageDataset/True/6027.png
#   inflating: content/TitanicImageDataset/True/2465.png
#   inflating: content/TitanicImageDataset/True/8668.png
#   inflating: content/TitanicImageDataset/True/5201.png
#   inflating: content/TitanicImageDataset/True/4971.png
#   inflating: content/TitanicImageDataset/True/4767.png
#   inflating: content/TitanicImageDataset/True/6097.png
#   inflating: content/TitanicImageDataset/True/4412.png
#   inflating: content/TitanicImageDataset/True/5796.png
#   inflating: content/TitanicImageDataset/True/7496.png
#   inflating: content/TitanicImageDataset/True/1447.png
#   inflating: content/TitanicImageDataset/True/5630.png
#   inflating: content/TitanicImageDataset/True/4789.png
#   inflating: content/TitanicImageDataset/True/1299.png
#   inflating: content/TitanicImageDataset/True/8169.png
#   inflating: content/TitanicImageDataset/True/6643.png
#   inflating: content/TitanicImageDataset/True/4687.png
#   inflating: content/TitanicImageDataset/True/321.png
#   inflating: content/TitanicImageDataset/True/686.png
#   inflating: content/TitanicImageDataset/True/915.png
#   inflating: content/TitanicImageDataset/True/5555.png
#   inflating: content/TitanicImageDataset/True/696.png
#   inflating: content/TitanicImageDataset/True/8393.png
#   inflating: content/TitanicImageDataset/True/726.png
#   inflating: content/TitanicImageDataset/True/8016.png
#   inflating: content/TitanicImageDataset/True/2495.png
#   inflating: content/TitanicImageDataset/True/6517.png
#   inflating: content/TitanicImageDataset/True/4423.png
#   inflating: content/TitanicImageDataset/True/7964.png
#   inflating: content/TitanicImageDataset/True/4334.png
#   inflating: content/TitanicImageDataset/True/6496.png
#   inflating: content/TitanicImageDataset/True/6160.png
#   inflating: content/TitanicImageDataset/True/4923.png
#   inflating: content/TitanicImageDataset/True/5486.png
#   inflating: content/TitanicImageDataset/True/7158.png
#   inflating: content/TitanicImageDataset/True/2117.png
#   inflating: content/TitanicImageDataset/True/2554.png
#   inflating: content/TitanicImageDataset/True/6640.png
#   inflating: content/TitanicImageDataset/True/4165.png
#   inflating: content/TitanicImageDataset/True/2193.png
#   inflating: content/TitanicImageDataset/True/7381.png
#   inflating: content/TitanicImageDataset/True/77.png
#   inflating: content/TitanicImageDataset/True/3115.png
#   inflating: content/TitanicImageDataset/True/7220.png
#   inflating: content/TitanicImageDataset/True/1652.png
#   inflating: content/TitanicImageDataset/True/5374.png
#   inflating: content/TitanicImageDataset/True/2658.png
#   inflating: content/TitanicImageDataset/True/8311.png
#   inflating: content/TitanicImageDataset/True/8446.png
#   inflating: content/TitanicImageDataset/True/6524.png
#   inflating: content/TitanicImageDataset/True/7292.png
#   inflating: content/TitanicImageDataset/True/4910.png
#   inflating: content/TitanicImageDataset/True/1184.png
#   inflating: content/TitanicImageDataset/True/2779.png
#   inflating: content/TitanicImageDataset/True/3787.png
#   inflating: content/TitanicImageDataset/True/2125.png
#   inflating: content/TitanicImageDataset/True/2862.png
#   inflating: content/TitanicImageDataset/True/1863.png
#   inflating: content/TitanicImageDataset/True/6356.png
#   inflating: content/TitanicImageDataset/True/6990.png
#   inflating: content/TitanicImageDataset/True/2244.png
#   inflating: content/TitanicImageDataset/True/1780.png
#   inflating: content/TitanicImageDataset/True/221.png
#   inflating: content/TitanicImageDataset/True/3298.png
#   inflating: content/TitanicImageDataset/True/6867.png
#   inflating: content/TitanicImageDataset/True/7174.png
#   inflating: content/TitanicImageDataset/True/3906.png
#   inflating: content/TitanicImageDataset/True/4092.png
#   inflating: content/TitanicImageDataset/True/546.png
#   inflating: content/TitanicImageDataset/True/4617.png
#   inflating: content/TitanicImageDataset/True/768.png
#   inflating: content/TitanicImageDataset/True/5454.png
#   inflating: content/TitanicImageDataset/True/8149.png
#   inflating: content/TitanicImageDataset/True/493.png
#   inflating: content/TitanicImageDataset/True/6694.png
#   inflating: content/TitanicImageDataset/True/5513.png
#   inflating: content/TitanicImageDataset/True/481.png
#   inflating: content/TitanicImageDataset/True/5171.png
#   inflating: content/TitanicImageDataset/True/4407.png
#   inflating: content/TitanicImageDataset/True/3382.png
#   inflating: content/TitanicImageDataset/True/7187.png
#   inflating: content/TitanicImageDataset/True/869.png
#   inflating: content/TitanicImageDataset/True/1832.png
#   inflating: content/TitanicImageDataset/True/8093.png
#   inflating: content/TitanicImageDataset/True/3032.png
#   inflating: content/TitanicImageDataset/True/8261.png
#   inflating: content/TitanicImageDataset/True/8030.png
#   inflating: content/TitanicImageDataset/True/1287.png
#   inflating: content/TitanicImageDataset/True/3461.png
#   inflating: content/TitanicImageDataset/True/2637.png
#   inflating: content/TitanicImageDataset/True/8282.png
#   inflating: content/TitanicImageDataset/True/4784.png
#   inflating: content/TitanicImageDataset/True/4867.png
#   inflating: content/TitanicImageDataset/True/2875.png
#   inflating: content/TitanicImageDataset/True/7485.png
#   inflating: content/TitanicImageDataset/True/6336.png
#   inflating: content/TitanicImageDataset/True/1924.png
#   inflating: content/TitanicImageDataset/True/5220.png
#   inflating: content/TitanicImageDataset/True/7182.png
#   inflating: content/TitanicImageDataset/True/1568.png
#   inflating: content/TitanicImageDataset/True/4113.png
#   inflating: content/TitanicImageDataset/True/5184.png
#   inflating: content/TitanicImageDataset/True/3912.png
#   inflating: content/TitanicImageDataset/True/2369.png
#   inflating: content/TitanicImageDataset/True/504.png
#   inflating: content/TitanicImageDataset/True/6991.png
#   inflating: content/TitanicImageDataset/True/2946.png
#   inflating: content/TitanicImageDataset/True/151.png
#   inflating: content/TitanicImageDataset/True/4905.png
#   inflating: content/TitanicImageDataset/True/4856.png
#   inflating: content/TitanicImageDataset/True/517.png
#   inflating: content/TitanicImageDataset/True/2898.png
#   inflating: content/TitanicImageDataset/True/5685.png
#   inflating: content/TitanicImageDataset/True/4031.png
#   inflating: content/TitanicImageDataset/True/2383.png
#   inflating: content/TitanicImageDataset/True/3329.png
#   inflating: content/TitanicImageDataset/True/6436.png
#   inflating: content/TitanicImageDataset/True/95.png
#   inflating: content/TitanicImageDataset/True/3990.png
#   inflating: content/TitanicImageDataset/True/1722.png
#   inflating: content/TitanicImageDataset/True/513.png
#   inflating: content/TitanicImageDataset/True/7374.png
#   inflating: content/TitanicImageDataset/True/2760.png
#   inflating: content/TitanicImageDataset/True/4106.png
#   inflating: content/TitanicImageDataset/True/2981.png
#   inflating: content/TitanicImageDataset/True/5735.png
#   inflating: content/TitanicImageDataset/True/4900.png
#   inflating: content/TitanicImageDataset/True/3297.png
#   inflating: content/TitanicImageDataset/True/6778.png
#   inflating: content/TitanicImageDataset/True/3420.png
#   inflating: content/TitanicImageDataset/True/5862.png
#   inflating: content/TitanicImageDataset/True/2578.png
#   inflating: content/TitanicImageDataset/True/674.png
#   inflating: content/TitanicImageDataset/True/5647.png
#   inflating: content/TitanicImageDataset/True/6096.png
#   inflating: content/TitanicImageDataset/True/3943.png
#   inflating: content/TitanicImageDataset/True/4157.png
#   inflating: content/TitanicImageDataset/True/745.png
#   inflating: content/TitanicImageDataset/True/3450.png
#   inflating: content/TitanicImageDataset/True/5893.png
#   inflating: content/TitanicImageDataset/True/4110.png
#   inflating: content/TitanicImageDataset/True/6938.png
#   inflating: content/TitanicImageDataset/True/2772.png
#   inflating: content/TitanicImageDataset/True/2901.png
#   inflating: content/TitanicImageDataset/True/304.png
#   inflating: content/TitanicImageDataset/True/8648.png
#   inflating: content/TitanicImageDataset/True/6445.png
#   inflating: content/TitanicImageDataset/True/3693.png
#   inflating: content/TitanicImageDataset/True/2252.png
#   inflating: content/TitanicImageDataset/True/4091.png
#   inflating: content/TitanicImageDataset/True/2083.png
#   inflating: content/TitanicImageDataset/True/8595.png
#   inflating: content/TitanicImageDataset/True/5101.png
#   inflating: content/TitanicImageDataset/True/744.png
#   inflating: content/TitanicImageDataset/True/4970.png
#   inflating: content/TitanicImageDataset/True/1526.png
#   inflating: content/TitanicImageDataset/True/684.png
#   inflating: content/TitanicImageDataset/True/6721.png
#   inflating: content/TitanicImageDataset/True/7605.png
#   inflating: content/TitanicImageDataset/False/7641.png
#   inflating: content/TitanicImageDataset/False/7945.png
#   inflating: content/TitanicImageDataset/False/8381.png
#   inflating: content/TitanicImageDataset/False/7234.png
#   inflating: content/TitanicImageDataset/False/1263.png
#   inflating: content/TitanicImageDataset/False/5885.png
#   inflating: content/TitanicImageDataset/False/1959.png
#   inflating: content/TitanicImageDataset/False/2957.png
#   inflating: content/TitanicImageDataset/False/1591.png
#   inflating: content/TitanicImageDataset/False/4711.png
#   inflating: content/TitanicImageDataset/False/1818.png
#   inflating: content/TitanicImageDataset/False/6681.png
#   inflating: content/TitanicImageDataset/False/4457.png
#   inflating: content/TitanicImageDataset/False/4845.png
#   inflating: content/TitanicImageDataset/False/2822.png
#   inflating: content/TitanicImageDataset/False/3134.png
#   inflating: content/TitanicImageDataset/False/353.png
#   inflating: content/TitanicImageDataset/False/4520.png
#   inflating: content/TitanicImageDataset/False/8190.png
#   inflating: content/TitanicImageDataset/False/2459.png
#   inflating: content/TitanicImageDataset/False/2931.png
#   inflating: content/TitanicImageDataset/False/7897.png
#   inflating: content/TitanicImageDataset/False/4749.png
#   inflating: content/TitanicImageDataset/False/4755.png
#   inflating: content/TitanicImageDataset/False/5219.png
#   inflating: content/TitanicImageDataset/False/735.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/TitanicImageDataset", output="/content/content/TitanicSplit", seed=1337, ratio=(.80,  .20), group_prefix=None) # default values
# Out:
# Copying files: 8693 files [00:01, 5810.09 files/s]

# %%
import os
os.listdir("/content/content/TitanicSplit")
# Out:
# ['val', 'train']

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/TitanicSplit/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 6954, 'val': 1739}, ['False', 'True'], device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# Densenet

# %%
model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
model_ft = models.densenet121(pretrained=False)
#num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
optimizer_ft = optim.Adamax(model_ft.parameters(), lr=0.001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.0854 Acc: 0.9928
# val Loss: 0.0004 Acc: 1.0000
#
# Epoch 1/4
# ----------
# train Loss: 0.0014 Acc: 1.0000
# val Loss: 0.0002 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0001 Acc: 1.0000
#
# Training complete in 5m 48s
# Best val Acc: 1.000000

# %%
torch.save(model_ft, "Titanic_Densenet.pth")
model_ft = torch.load("/content/Titanic_Densenet.pth")

# %%
nb_classes = len(class_names)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model_ft(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

#print(confusion_matrix)

#print(confusion_matrix.diag()/confusion_matrix.sum(1))

plt.figure(figsize=(3,3))

# class_names = ['0','1']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')

#print('Test accuracy:{:.4f}'.format(correct.double() / dataset_sizes['val']))
print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Sensitivity:  tensor(100.)
# Specificity:  tensor(100.)
# PPV:  tensor(100.)
# NPV:  tensor(100.)

# %%
def getConfusionMatrix(model, show_image=False):
    model.eval() #set the model to evaluation mode
    confusion_matrix=np.zeros((2,2),dtype=int) #initialize a confusion matrix
    num_images=dataloaders['val'] #size of the testset
    
    with torch.no_grad(): #disable back prop to test the model
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            #get predictions of the model
            outputs = model(inputs) 
            _, preds = torch.max(outputs, 1) 
            
            #get confusion matrix
            for j in range(inputs.size()[0]): 
                if preds[j]==1 and labels[j]==1:
                    term='TP'
                    confusion_matrix[0][0]+=1
                elif preds[j]==1 and labels[j]==0:
                    term='FP'
                    confusion_matrix[1][0]+=1
                elif preds[j]==0 and labels[j]==1:
                    term='FN'
                    confusion_matrix[0][1]+=1
                elif preds[j]==0 and labels[j]==0:
                    term='TN'
                    confusion_matrix[1][1]+=1
                #show image and its class in confusion matrix    
                if show_image:
                    print('predicted: {}'.format(class_names[preds[j]]))
                    print(term)
                    imshow(inputs.cpu().data[j])
                    print()
        #print results
        print('Confusion Matrix: ')
        print(confusion_matrix)
        print()
        print('Sensitivity: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]))
        print('Specificity: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[1][0]))
        print('PPV: ', 100*confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]))
        print('NPV: ', 100*confusion_matrix[1][1]/(confusion_matrix[1][1]+confusion_matrix[0][1]))
        
        return confusion_matrix

# %% [markdown]
# 7) Titanic

# %%
# !gdown --id 1dm5qVnbWSmwfSsOoFbTHs7oBGD2zwpxr
#For zip Dataset Folders
# !unzip /content/TitanicImageDataset.zip

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/TitanicImageDataset", output="/content/content/TitanicSplit", seed=1337, ratio=(.80,  .20), group_prefix=None) # default values

# %%
os.listdir("/content/content/TitanicSplit")

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/TitanicSplit/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
dataset_sizes, class_names, device

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# Resnet-18

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
#optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)

# %% [markdown]
# 7)Titanic Dataset

# %%
# !gdown --id 1dm5qVnbWSmwfSsOoFbTHs7oBGD2zwpxr
#For zip Dataset Folders
# !unzip /content/TitanicImageDataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/TitanicImageDataset/True/4180.png
#   inflating: content/TitanicImageDataset/True/1116.png
#   inflating: content/TitanicImageDataset/True/314.png
#   inflating: content/TitanicImageDataset/True/2435.png
#   inflating: content/TitanicImageDataset/True/3181.png
#   inflating: content/TitanicImageDataset/True/4279.png
#   inflating: content/TitanicImageDataset/True/4413.png
#   inflating: content/TitanicImageDataset/True/2159.png
#   inflating: content/TitanicImageDataset/True/5035.png
#   inflating: content/TitanicImageDataset/True/3024.png
#   inflating: content/TitanicImageDataset/True/6188.png
#   inflating: content/TitanicImageDataset/True/5920.png
#   inflating: content/TitanicImageDataset/True/7857.png
#   inflating: content/TitanicImageDataset/True/6159.png
#   inflating: content/TitanicImageDataset/True/5266.png
#   inflating: content/TitanicImageDataset/True/7205.png
#   inflating: content/TitanicImageDataset/True/5206.png
#   inflating: content/TitanicImageDataset/True/2916.png
#   inflating: content/TitanicImageDataset/True/2251.png
#   inflating: content/TitanicImageDataset/True/2170.png
#   inflating: content/TitanicImageDataset/True/473.png
#   inflating: content/TitanicImageDataset/True/4829.png
#   inflating: content/TitanicImageDataset/True/6875.png
#   inflating: content/TitanicImageDataset/True/4247.png
#   inflating: content/TitanicImageDataset/True/6937.png
#   inflating: content/TitanicImageDataset/True/7704.png
#   inflating: content/TitanicImageDataset/True/7652.png
#   inflating: content/TitanicImageDataset/True/7149.png
#   inflating: content/TitanicImageDataset/True/4170.png
#   inflating: content/TitanicImageDataset/True/3961.png
#   inflating: content/TitanicImageDataset/True/7141.png
#   inflating: content/TitanicImageDataset/True/2088.png
#   inflating: content/TitanicImageDataset/True/1454.png
#   inflating: content/TitanicImageDataset/True/1904.png
#   inflating: content/TitanicImageDataset/True/3962.png
#   inflating: content/TitanicImageDataset/True/300.png
#   inflating: content/TitanicImageDataset/True/5165.png
#   inflating: content/TitanicImageDataset/True/7263.png
#   inflating: content/TitanicImageDataset/True/3767.png
#   inflating: content/TitanicImageDataset/True/6946.png
#   inflating: content/TitanicImageDataset/True/7517.png
#   inflating: content/TitanicImageDataset/True/6935.png
#   inflating: content/TitanicImageDataset/True/5137.png
#   inflating: content/TitanicImageDataset/True/7437.png
#   inflating: content/TitanicImageDataset/True/5613.png
#   inflating: content/TitanicImageDataset/True/5195.png
#   inflating: content/TitanicImageDataset/True/6738.png
#   inflating: content/TitanicImageDataset/True/5836.png
#   inflating: content/TitanicImageDataset/True/7947.png
#   inflating: content/TitanicImageDataset/True/7592.png
#   inflating: content/TitanicImageDataset/True/5395.png
#   inflating: content/TitanicImageDataset/True/5567.png
#   inflating: content/TitanicImageDataset/True/7431.png
#   inflating: content/TitanicImageDataset/True/6682.png
#   inflating: content/TitanicImageDataset/True/8220.png
#   inflating: content/TitanicImageDataset/True/3724.png
#   inflating: content/TitanicImageDataset/True/3667.png
#   inflating: content/TitanicImageDataset/True/7994.png
#   inflating: content/TitanicImageDataset/True/8332.png
#   inflating: content/TitanicImageDataset/True/1412.png
#   inflating: content/TitanicImageDataset/True/4372.png
#   inflating: content/TitanicImageDataset/True/7278.png
#   inflating: content/TitanicImageDataset/True/5040.png
#   inflating: content/TitanicImageDataset/True/8096.png
#   inflating: content/TitanicImageDataset/True/6559.png
#   inflating: content/TitanicImageDataset/True/3388.png
#   inflating: content/TitanicImageDataset/True/8076.png
#   inflating: content/TitanicImageDataset/True/4590.png
#   inflating: content/TitanicImageDataset/True/1121.png
#   inflating: content/TitanicImageDataset/True/1675.png
#   inflating: content/TitanicImageDataset/True/3112.png
#   inflating: content/TitanicImageDataset/True/5455.png
#   inflating: content/TitanicImageDataset/True/4060.png
#   inflating: content/TitanicImageDataset/True/5752.png
#   inflating: content/TitanicImageDataset/True/5546.png
#   inflating: content/TitanicImageDataset/True/7793.png
#   inflating: content/TitanicImageDataset/True/6117.png
#   inflating: content/TitanicImageDataset/True/6448.png
#   inflating: content/TitanicImageDataset/True/5384.png
#   inflating: content/TitanicImageDataset/True/4913.png
#   inflating: content/TitanicImageDataset/True/2536.png
#   inflating: content/TitanicImageDataset/True/1362.png
#   inflating: content/TitanicImageDataset/True/8224.png
#   inflating: content/TitanicImageDataset/True/4163.png
#   inflating: content/TitanicImageDataset/True/2630.png
#   inflating: content/TitanicImageDataset/True/3407.png
#   inflating: content/TitanicImageDataset/True/6710.png
#   inflating: content/TitanicImageDataset/True/2840.png
#   inflating: content/TitanicImageDataset/True/4598.png
#   inflating: content/TitanicImageDataset/True/6508.png
#   inflating: content/TitanicImageDataset/True/8544.png
#   inflating: content/TitanicImageDataset/True/4230.png
#   inflating: content/TitanicImageDataset/True/2720.png
#   inflating: content/TitanicImageDataset/True/3774.png
#   inflating: content/TitanicImageDataset/True/1159.png
#   inflating: content/TitanicImageDataset/True/1301.png
#   inflating: content/TitanicImageDataset/True/6349.png
#   inflating: content/TitanicImageDataset/True/2655.png
#   inflating: content/TitanicImageDataset/True/4518.png
#   inflating: content/TitanicImageDataset/True/7115.png
#   inflating: content/TitanicImageDataset/True/8499.png
#   inflating: content/TitanicImageDataset/True/4866.png
#   inflating: content/TitanicImageDataset/True/3042.png
#   inflating: content/TitanicImageDataset/True/7384.png
#   inflating: content/TitanicImageDataset/True/7475.png
#   inflating: content/TitanicImageDataset/True/5098.png
#   inflating: content/TitanicImageDataset/True/1505.png
#   inflating: content/TitanicImageDataset/True/4854.png
#   inflating: content/TitanicImageDataset/True/2592.png
#   inflating: content/TitanicImageDataset/True/4912.png
#   inflating: content/TitanicImageDataset/True/7458.png
#   inflating: content/TitanicImageDataset/True/5446.png
#   inflating: content/TitanicImageDataset/True/5133.png
#   inflating: content/TitanicImageDataset/True/4051.png
#   inflating: content/TitanicImageDataset/True/4409.png
#   inflating: content/TitanicImageDataset/True/7377.png
#   inflating: content/TitanicImageDataset/True/8328.png
#   inflating: content/TitanicImageDataset/True/4014.png
#   inflating: content/TitanicImageDataset/True/5004.png
#   inflating: content/TitanicImageDataset/True/7535.png
#   inflating: content/TitanicImageDataset/True/5520.png
#   inflating: content/TitanicImageDataset/True/2263.png
#   inflating: content/TitanicImageDataset/True/8256.png
#   inflating: content/TitanicImageDataset/True/3160.png
#   inflating: content/TitanicImageDataset/True/4558.png
#   inflating: content/TitanicImageDataset/True/245.png
#   inflating: content/TitanicImageDataset/True/5532.png
#   inflating: content/TitanicImageDataset/True/1114.png
#   inflating: content/TitanicImageDataset/True/7634.png
#   inflating: content/TitanicImageDataset/True/4895.png
#   inflating: content/TitanicImageDataset/True/5778.png
#   inflating: content/TitanicImageDataset/True/2012.png
#   inflating: content/TitanicImageDataset/True/7730.png
#   inflating: content/TitanicImageDataset/True/416.png
#   inflating: content/TitanicImageDataset/True/1139.png
#   inflating: content/TitanicImageDataset/True/2313.png
#   inflating: content/TitanicImageDataset/True/3917.png
#   inflating: content/TitanicImageDataset/True/6338.png
#   inflating: content/TitanicImageDataset/True/8310.png
#   inflating: content/TitanicImageDataset/True/8511.png
#   inflating: content/TitanicImageDataset/True/3038.png
#   inflating: content/TitanicImageDataset/True/115.png
#   inflating: content/TitanicImageDataset/True/6395.png
#   inflating: content/TitanicImageDataset/True/1.png
#   inflating: content/TitanicImageDataset/True/41.png
#   inflating: content/TitanicImageDataset/True/6137.png
#   inflating: content/TitanicImageDataset/True/7049.png
#   inflating: content/TitanicImageDataset/True/980.png
#   inflating: content/TitanicImageDataset/True/4420.png
#   inflating: content/TitanicImageDataset/True/6711.png
#   inflating: content/TitanicImageDataset/True/2247.png
#   inflating: content/TitanicImageDataset/True/524.png
#   inflating: content/TitanicImageDataset/True/6995.png
#   inflating: content/TitanicImageDataset/True/3059.png
#   inflating: content/TitanicImageDataset/True/1882.png
#   inflating: content/TitanicImageDataset/True/8043.png
#   inflating: content/TitanicImageDataset/True/7255.png
#   inflating: content/TitanicImageDataset/True/1889.png
#   inflating: content/TitanicImageDataset/True/711.png
#   inflating: content/TitanicImageDataset/True/2867.png
#   inflating: content/TitanicImageDataset/True/4494.png
#   inflating: content/TitanicImageDataset/True/8494.png
#   inflating: content/TitanicImageDataset/True/5600.png
#   inflating: content/TitanicImageDataset/True/3017.png
#   inflating: content/TitanicImageDataset/True/6663.png
#   inflating: content/TitanicImageDataset/True/1954.png
#   inflating: content/TitanicImageDataset/True/6545.png
#   inflating: content/TitanicImageDataset/True/7283.png
#   inflating: content/TitanicImageDataset/True/2181.png
#   inflating: content/TitanicImageDataset/True/2971.png
#   inflating: content/TitanicImageDataset/True/6581.png
#   inflating: content/TitanicImageDataset/True/3315.png
#   inflating: content/TitanicImageDataset/True/2424.png
#   inflating: content/TitanicImageDataset/True/4361.png
#   inflating: content/TitanicImageDataset/True/487.png
#   inflating: content/TitanicImageDataset/True/7123.png
#   inflating: content/TitanicImageDataset/True/4914.png
#   inflating: content/TitanicImageDataset/True/4177.png
#   inflating: content/TitanicImageDataset/True/3979.png
#   inflating: content/TitanicImageDataset/True/7588.png
#   inflating: content/TitanicImageDataset/True/412.png
#   inflating: content/TitanicImageDataset/True/3296.png
#   inflating: content/TitanicImageDataset/True/306.png
#   inflating: content/TitanicImageDataset/True/8386.png
#   inflating: content/TitanicImageDataset/True/1961.png
#   inflating: content/TitanicImageDataset/True/5477.png
#   inflating: content/TitanicImageDataset/True/260.png
#   inflating: content/TitanicImageDataset/True/4400.png
#   inflating: content/TitanicImageDataset/True/4532.png
#   inflating: content/TitanicImageDataset/True/994.png
#   inflating: content/TitanicImageDataset/True/5939.png
#   inflating: content/TitanicImageDataset/True/6620.png
#   inflating: content/TitanicImageDataset/True/7901.png
#   inflating: content/TitanicImageDataset/True/2561.png
#   inflating: content/TitanicImageDataset/True/3377.png
#   inflating: content/TitanicImageDataset/True/5895.png
#   inflating: content/TitanicImageDataset/True/1067.png
#   inflating: content/TitanicImageDataset/True/6039.png
#   inflating: content/TitanicImageDataset/True/3212.png
#   inflating: content/TitanicImageDataset/True/679.png
#   inflating: content/TitanicImageDataset/True/6618.png
#   inflating: content/TitanicImageDataset/True/8268.png
#   inflating: content/TitanicImageDataset/True/5073.png
#   inflating: content/TitanicImageDataset/True/918.png
#   inflating: content/TitanicImageDataset/True/1496.png
#   inflating: content/TitanicImageDataset/True/8176.png
#   inflating: content/TitanicImageDataset/True/5638.png
#   inflating: content/TitanicImageDataset/True/1066.png
#   inflating: content/TitanicImageDataset/True/1149.png
#   inflating: content/TitanicImageDataset/True/3449.png
#   inflating: content/TitanicImageDataset/True/5670.png
#   inflating: content/TitanicImageDataset/True/6667.png
#   inflating: content/TitanicImageDataset/True/6526.png
#   inflating: content/TitanicImageDataset/True/8627.png
#   inflating: content/TitanicImageDataset/True/4773.png
#   inflating: content/TitanicImageDataset/True/4628.png
#   inflating: content/TitanicImageDataset/True/5353.png
#   inflating: content/TitanicImageDataset/True/7805.png
#   inflating: content/TitanicImageDataset/True/7979.png
#   inflating: content/TitanicImageDataset/True/970.png
#   inflating: content/TitanicImageDataset/True/1848.png
#   inflating: content/TitanicImageDataset/True/2162.png
#   inflating: content/TitanicImageDataset/True/8177.png
#   inflating: content/TitanicImageDataset/True/1379.png
#   inflating: content/TitanicImageDataset/True/6993.png
#   inflating: content/TitanicImageDataset/True/1403.png
#   inflating: content/TitanicImageDataset/True/5747.png
#   inflating: content/TitanicImageDataset/True/5156.png
#   inflating: content/TitanicImageDataset/True/4241.png
#   inflating: content/TitanicImageDataset/True/3389.png
#   inflating: content/TitanicImageDataset/True/3650.png
#   inflating: content/TitanicImageDataset/True/1831.png
#   inflating: content/TitanicImageDataset/True/3617.png
#   inflating: content/TitanicImageDataset/True/5086.png
#   inflating: content/TitanicImageDataset/True/6980.png
#   inflating: content/TitanicImageDataset/True/4967.png
#   inflating: content/TitanicImageDataset/True/4548.png
#   inflating: content/TitanicImageDataset/True/4903.png
#   inflating: content/TitanicImageDataset/True/1198.png
#   inflating: content/TitanicImageDataset/True/5361.png
#   inflating: content/TitanicImageDataset/True/5274.png
#   inflating: content/TitanicImageDataset/True/6330.png
#   inflating: content/TitanicImageDataset/True/6104.png
#   inflating: content/TitanicImageDataset/True/2343.png
#   inflating: content/TitanicImageDataset/True/7169.png
#   inflating: content/TitanicImageDataset/True/1967.png
#   inflating: content/TitanicImageDataset/True/5695.png
#   inflating: content/TitanicImageDataset/True/1491.png
#   inflating: content/TitanicImageDataset/True/3415.png
#   inflating: content/TitanicImageDataset/True/2430.png
#   inflating: content/TitanicImageDataset/True/1571.png
#   inflating: content/TitanicImageDataset/True/257.png
#   inflating: content/TitanicImageDataset/True/6406.png
#   inflating: content/TitanicImageDataset/True/8303.png
#   inflating: content/TitanicImageDataset/True/6501.png
#   inflating: content/TitanicImageDataset/True/187.png
#   inflating: content/TitanicImageDataset/True/4664.png
#   inflating: content/TitanicImageDataset/True/1674.png
#   inflating: content/TitanicImageDataset/True/2974.png
#   inflating: content/TitanicImageDataset/True/2910.png
#   inflating: content/TitanicImageDataset/True/5488.png
#   inflating: content/TitanicImageDataset/True/1371.png
#   inflating: content/TitanicImageDataset/True/3534.png
#   inflating: content/TitanicImageDataset/True/1494.png
#   inflating: content/TitanicImageDataset/True/6084.png
#   inflating: content/TitanicImageDataset/True/3052.png
#   inflating: content/TitanicImageDataset/True/8110.png
#   inflating: content/TitanicImageDataset/True/6228.png
#   inflating: content/TitanicImageDataset/True/3680.png
#   inflating: content/TitanicImageDataset/True/5574.png
#   inflating: content/TitanicImageDataset/True/4018.png
#   inflating: content/TitanicImageDataset/True/2853.png
#   inflating: content/TitanicImageDataset/True/4983.png
#   inflating: content/TitanicImageDataset/True/7034.png
#   inflating: content/TitanicImageDataset/True/7163.png
#   inflating: content/TitanicImageDataset/True/6976.png
#   inflating: content/TitanicImageDataset/True/4953.png
#   inflating: content/TitanicImageDataset/True/5189.png
#   inflating: content/TitanicImageDataset/True/1103.png
#   inflating: content/TitanicImageDataset/True/1732.png
#   inflating: content/TitanicImageDataset/True/543.png
#   inflating: content/TitanicImageDataset/True/4111.png
#   inflating: content/TitanicImageDataset/True/6441.png
#   inflating: content/TitanicImageDataset/True/2450.png
#   inflating: content/TitanicImageDataset/True/4700.png
#   inflating: content/TitanicImageDataset/True/1063.png
#   inflating: content/TitanicImageDataset/True/8570.png
#   inflating: content/TitanicImageDataset/True/4139.png
#   inflating: content/TitanicImageDataset/True/3075.png
#   inflating: content/TitanicImageDataset/True/5686.png
#   inflating: content/TitanicImageDataset/True/3727.png
#   inflating: content/TitanicImageDataset/True/7918.png
#   inflating: content/TitanicImageDataset/True/1721.png
#   inflating: content/TitanicImageDataset/True/7523.png
#   inflating: content/TitanicImageDataset/True/619.png
#   inflating: content/TitanicImageDataset/True/557.png
#   inflating: content/TitanicImageDataset/True/2456.png
#   inflating: content/TitanicImageDataset/True/4147.png
#   inflating: content/TitanicImageDataset/True/4002.png
#   inflating: content/TitanicImageDataset/True/7643.png
#   inflating: content/TitanicImageDataset/True/988.png
#   inflating: content/TitanicImageDataset/True/5541.png
#   inflating: content/TitanicImageDataset/True/4920.png
#   inflating: content/TitanicImageDataset/True/7396.png
#   inflating: content/TitanicImageDataset/True/2150.png
#   inflating: content/TitanicImageDataset/True/759.png
#   inflating: content/TitanicImageDataset/True/3967.png
#   inflating: content/TitanicImageDataset/True/2943.png
#   inflating: content/TitanicImageDataset/True/1061.png
#   inflating: content/TitanicImageDataset/True/1948.png
#   inflating: content/TitanicImageDataset/True/8002.png
#   inflating: content/TitanicImageDataset/True/93.png
#   inflating: content/TitanicImageDataset/True/4998.png
#   inflating: content/TitanicImageDataset/True/976.png
#   inflating: content/TitanicImageDataset/True/1161.png
#   inflating: content/TitanicImageDataset/True/1641.png
#   inflating: content/TitanicImageDataset/True/6879.png
#   inflating: content/TitanicImageDataset/True/1147.png
#   inflating: content/TitanicImageDataset/True/3463.png
#   inflating: content/TitanicImageDataset/True/8107.png
#   inflating: content/TitanicImageDataset/True/3498.png
#   inflating: content/TitanicImageDataset/True/6589.png
#   inflating: content/TitanicImageDataset/True/6780.png
#   inflating: content/TitanicImageDataset/True/8362.png
#   inflating: content/TitanicImageDataset/True/2378.png
#   inflating: content/TitanicImageDataset/True/145.png
#   inflating: content/TitanicImageDataset/True/4703.png
#   inflating: content/TitanicImageDataset/True/3356.png
#   inflating: content/TitanicImageDataset/True/4937.png
#   inflating: content/TitanicImageDataset/True/1939.png
#   inflating: content/TitanicImageDataset/True/2969.png
#   inflating: content/TitanicImageDataset/True/6449.png
#   inflating: content/TitanicImageDataset/True/3357.png
#   inflating: content/TitanicImageDataset/True/4579.png
#   inflating: content/TitanicImageDataset/True/8358.png
#   inflating: content/TitanicImageDataset/True/8489.png
#   inflating: content/TitanicImageDataset/True/4918.png
#   inflating: content/TitanicImageDataset/True/7550.png
#   inflating: content/TitanicImageDataset/True/3429.png
#   inflating: content/TitanicImageDataset/True/4016.png
#   inflating: content/TitanicImageDataset/True/3731.png
#   inflating: content/TitanicImageDataset/True/1804.png
#   inflating: content/TitanicImageDataset/True/511.png
#   inflating: content/TitanicImageDataset/True/4621.png
#   inflating: content/TitanicImageDataset/True/4357.png
#   inflating: content/TitanicImageDataset/True/8341.png
#   inflating: content/TitanicImageDataset/True/6169.png
#   inflating: content/TitanicImageDataset/True/8197.png
#   inflating: content/TitanicImageDataset/True/3583.png
#   inflating: content/TitanicImageDataset/True/6964.png
#   inflating: content/TitanicImageDataset/True/35.png
#   inflating: content/TitanicImageDataset/True/4989.png
#   inflating: content/TitanicImageDataset/True/7692.png
#   inflating: content/TitanicImageDataset/True/4239.png
#   inflating: content/TitanicImageDataset/True/5616.png
#   inflating: content/TitanicImageDataset/True/7613.png
#   inflating: content/TitanicImageDataset/True/1250.png
#   inflating: content/TitanicImageDataset/True/4021.png
#   inflating: content/TitanicImageDataset/True/6225.png
#   inflating: content/TitanicImageDataset/True/3168.png
#   inflating: content/TitanicImageDataset/True/6089.png
#   inflating: content/TitanicImageDataset/True/5880.png
#   inflating: content/TitanicImageDataset/True/6371.png
#   inflating: content/TitanicImageDataset/True/4175.png
#   inflating: content/TitanicImageDataset/True/623.png
#   inflating: content/TitanicImageDataset/True/1031.png
#   inflating: content/TitanicImageDataset/True/8285.png
#   inflating: content/TitanicImageDataset/True/24.png
#   inflating: content/TitanicImageDataset/True/6279.png
#   inflating: content/TitanicImageDataset/True/4943.png
#   inflating: content/TitanicImageDataset/True/7740.png
#   inflating: content/TitanicImageDataset/True/4545.png
#   inflating: content/TitanicImageDataset/True/6471.png
#   inflating: content/TitanicImageDataset/True/1306.png
#   inflating: content/TitanicImageDataset/True/4042.png
#   inflating: content/TitanicImageDataset/True/7258.png
#   inflating: content/TitanicImageDataset/True/3969.png
#   inflating: content/TitanicImageDataset/True/682.png
#   inflating: content/TitanicImageDataset/True/8349.png
#   inflating: content/TitanicImageDataset/True/3584.png
#   inflating: content/TitanicImageDataset/True/5780.png
#   inflating: content/TitanicImageDataset/True/4534.png
#   inflating: content/TitanicImageDataset/True/6932.png
#   inflating: content/TitanicImageDataset/True/7756.png
#   inflating: content/TitanicImageDataset/True/3831.png
#   inflating: content/TitanicImageDataset/True/7537.png
#   inflating: content/TitanicImageDataset/True/536.png
#   inflating: content/TitanicImageDataset/True/5200.png
#   inflating: content/TitanicImageDataset/True/4291.png
#   inflating: content/TitanicImageDataset/True/3813.png
#   inflating: content/TitanicImageDataset/True/1918.png
#   inflating: content/TitanicImageDataset/True/5877.png
#   inflating: content/TitanicImageDataset/True/7706.png
#   inflating: content/TitanicImageDataset/True/2204.png
#   inflating: content/TitanicImageDataset/True/4131.png
#   inflating: content/TitanicImageDataset/True/5329.png
#   inflating: content/TitanicImageDataset/True/3887.png
#   inflating: content/TitanicImageDataset/True/7227.png
#   inflating: content/TitanicImageDataset/True/3602.png
#   inflating: content/TitanicImageDataset/True/2493.png
#   inflating: content/TitanicImageDataset/True/5696.png
#   inflating: content/TitanicImageDataset/True/5315.png
#   inflating: content/TitanicImageDataset/True/5425.png
#   inflating: content/TitanicImageDataset/True/6041.png
#   inflating: content/TitanicImageDataset/True/7268.png
#   inflating: content/TitanicImageDataset/True/427.png
#   inflating: content/TitanicImageDataset/True/2629.png
#   inflating: content/TitanicImageDataset/True/2178.png
#   inflating: content/TitanicImageDataset/True/7030.png
#   inflating: content/TitanicImageDataset/True/4421.png
#   inflating: content/TitanicImageDataset/True/3280.png
#   inflating: content/TitanicImageDataset/True/4916.png
#   inflating: content/TitanicImageDataset/True/7769.png
#   inflating: content/TitanicImageDataset/True/7477.png
#   inflating: content/TitanicImageDataset/True/195.png
#   inflating: content/TitanicImageDataset/True/5071.png
#   inflating: content/TitanicImageDataset/True/4733.png
#   inflating: content/TitanicImageDataset/True/5800.png
#   inflating: content/TitanicImageDataset/True/4448.png
#   inflating: content/TitanicImageDataset/True/4715.png
#   inflating: content/TitanicImageDataset/True/2985.png
#   inflating: content/TitanicImageDataset/True/1448.png
#   inflating: content/TitanicImageDataset/True/6804.png
#   inflating: content/TitanicImageDataset/True/6491.png
#   inflating: content/TitanicImageDataset/True/5333.png
#   inflating: content/TitanicImageDataset/True/6708.png
#   inflating: content/TitanicImageDataset/True/2024.png
#   inflating: content/TitanicImageDataset/True/2700.png
#   inflating: content/TitanicImageDataset/True/3295.png
#   inflating: content/TitanicImageDataset/True/3810.png
#   inflating: content/TitanicImageDataset/True/8024.png
#   inflating: content/TitanicImageDataset/True/3101.png
#   inflating: content/TitanicImageDataset/True/2355.png
#   inflating: content/TitanicImageDataset/True/5761.png
#   inflating: content/TitanicImageDataset/True/8277.png
#   inflating: content/TitanicImageDataset/True/3728.png
#   inflating: content/TitanicImageDataset/True/676.png
#   inflating: content/TitanicImageDataset/True/6383.png
#   inflating: content/TitanicImageDataset/True/2543.png
#   inflating: content/TitanicImageDataset/True/4500.png
#   inflating: content/TitanicImageDataset/True/1026.png
#   inflating: content/TitanicImageDataset/True/7308.png
#   inflating: content/TitanicImageDataset/True/6555.png
#   inflating: content/TitanicImageDataset/True/2777.png
#   inflating: content/TitanicImageDataset/True/7008.png
#   inflating: content/TitanicImageDataset/True/5604.png
#   inflating: content/TitanicImageDataset/True/8412.png
#   inflating: content/TitanicImageDataset/True/6818.png
#   inflating: content/TitanicImageDataset/True/2102.png
#   inflating: content/TitanicImageDataset/True/8560.png
#   inflating: content/TitanicImageDataset/True/7464.png
#   inflating: content/TitanicImageDataset/True/580.png
#   inflating: content/TitanicImageDataset/True/5136.png
#   inflating: content/TitanicImageDataset/True/1173.png
#   inflating: content/TitanicImageDataset/True/1282.png
#   inflating: content/TitanicImageDataset/True/5227.png
#   inflating: content/TitanicImageDataset/True/6267.png
#   inflating: content/TitanicImageDataset/True/5452.png
#   inflating: content/TitanicImageDataset/True/4212.png
#   inflating: content/TitanicImageDataset/True/4288.png
#   inflating: content/TitanicImageDataset/True/6004.png
#   inflating: content/TitanicImageDataset/True/380.png
#   inflating: content/TitanicImageDataset/True/4594.png
#   inflating: content/TitanicImageDataset/True/5102.png
#   inflating: content/TitanicImageDataset/True/6623.png
#   inflating: content/TitanicImageDataset/True/1840.png
#   inflating: content/TitanicImageDataset/True/8513.png
#   inflating: content/TitanicImageDataset/True/2679.png
#   inflating: content/TitanicImageDataset/True/939.png
#   inflating: content/TitanicImageDataset/True/601.png
#   inflating: content/TitanicImageDataset/True/3577.png
#   inflating: content/TitanicImageDataset/True/202.png
#   inflating: content/TitanicImageDataset/True/6236.png
#   inflating: content/TitanicImageDataset/True/5992.png
#   inflating: content/TitanicImageDataset/True/2328.png
#   inflating: content/TitanicImageDataset/True/7703.png
#   inflating: content/TitanicImageDataset/True/1518.png
#   inflating: content/TitanicImageDataset/True/3570.png
#   inflating: content/TitanicImageDataset/True/8046.png
#   inflating: content/TitanicImageDataset/True/5903.png
#   inflating: content/TitanicImageDataset/True/807.png
#   inflating: content/TitanicImageDataset/True/857.png
#   inflating: content/TitanicImageDataset/True/1076.png
#   inflating: content/TitanicImageDataset/True/6339.png
#   inflating: content/TitanicImageDataset/True/429.png
#   inflating: content/TitanicImageDataset/True/7644.png
#   inflating: content/TitanicImageDataset/True/5702.png
#   inflating: content/TitanicImageDataset/True/5023.png
#   inflating: content/TitanicImageDataset/True/71.png
#   inflating: content/TitanicImageDataset/True/993.png
#   inflating: content/TitanicImageDataset/True/3054.png
#   inflating: content/TitanicImageDataset/True/3654.png
#   inflating: content/TitanicImageDataset/True/474.png
#   inflating: content/TitanicImageDataset/True/2417.png
#   inflating: content/TitanicImageDataset/True/4299.png
#   inflating: content/TitanicImageDataset/True/2634.png
#   inflating: content/TitanicImageDataset/True/6411.png
#   inflating: content/TitanicImageDataset/True/6055.png
#   inflating: content/TitanicImageDataset/True/7296.png
#   inflating: content/TitanicImageDataset/True/2892.png
#   inflating: content/TitanicImageDataset/True/6027.png
#   inflating: content/TitanicImageDataset/True/2465.png
#   inflating: content/TitanicImageDataset/True/8668.png
#   inflating: content/TitanicImageDataset/True/5201.png
#   inflating: content/TitanicImageDataset/True/4971.png
#   inflating: content/TitanicImageDataset/True/4767.png
#   inflating: content/TitanicImageDataset/True/6097.png
#   inflating: content/TitanicImageDataset/True/4412.png
#   inflating: content/TitanicImageDataset/True/5796.png
#   inflating: content/TitanicImageDataset/True/7496.png
#   inflating: content/TitanicImageDataset/True/1447.png
#   inflating: content/TitanicImageDataset/True/5630.png
#   inflating: content/TitanicImageDataset/True/4789.png
#   inflating: content/TitanicImageDataset/True/1299.png
#   inflating: content/TitanicImageDataset/True/8169.png
#   inflating: content/TitanicImageDataset/True/6643.png
#   inflating: content/TitanicImageDataset/True/4687.png
#   inflating: content/TitanicImageDataset/True/321.png
#   inflating: content/TitanicImageDataset/True/686.png
#   inflating: content/TitanicImageDataset/True/915.png
#   inflating: content/TitanicImageDataset/True/5555.png
#   inflating: content/TitanicImageDataset/True/696.png
#   inflating: content/TitanicImageDataset/True/8393.png
#   inflating: content/TitanicImageDataset/True/726.png
#   inflating: content/TitanicImageDataset/True/8016.png
#   inflating: content/TitanicImageDataset/True/2495.png
#   inflating: content/TitanicImageDataset/True/6517.png
#   inflating: content/TitanicImageDataset/True/4423.png
#   inflating: content/TitanicImageDataset/True/7964.png
#   inflating: content/TitanicImageDataset/True/4334.png
#   inflating: content/TitanicImageDataset/True/6496.png
#   inflating: content/TitanicImageDataset/True/6160.png
#   inflating: content/TitanicImageDataset/True/4923.png
#   inflating: content/TitanicImageDataset/True/5486.png
#   inflating: content/TitanicImageDataset/True/7158.png
#   inflating: content/TitanicImageDataset/True/2117.png
#   inflating: content/TitanicImageDataset/True/2554.png
#   inflating: content/TitanicImageDataset/True/6640.png
#   inflating: content/TitanicImageDataset/True/4165.png
#   inflating: content/TitanicImageDataset/True/2193.png
#   inflating: content/TitanicImageDataset/True/7381.png
#   inflating: content/TitanicImageDataset/True/77.png
#   inflating: content/TitanicImageDataset/True/3115.png
#   inflating: content/TitanicImageDataset/True/7220.png
#   inflating: content/TitanicImageDataset/True/1652.png
#   inflating: content/TitanicImageDataset/True/5374.png
#   inflating: content/TitanicImageDataset/True/2658.png
#   inflating: content/TitanicImageDataset/True/8311.png
#   inflating: content/TitanicImageDataset/True/8446.png
#   inflating: content/TitanicImageDataset/True/6524.png
#   inflating: content/TitanicImageDataset/True/7292.png
#   inflating: content/TitanicImageDataset/True/4910.png
#   inflating: content/TitanicImageDataset/True/1184.png
#   inflating: content/TitanicImageDataset/True/2779.png
#   inflating: content/TitanicImageDataset/True/3787.png
#   inflating: content/TitanicImageDataset/True/2125.png
#   inflating: content/TitanicImageDataset/True/2862.png
#   inflating: content/TitanicImageDataset/True/1863.png
#   inflating: content/TitanicImageDataset/True/6356.png
#   inflating: content/TitanicImageDataset/True/6990.png
#   inflating: content/TitanicImageDataset/True/2244.png
#   inflating: content/TitanicImageDataset/True/1780.png
#   inflating: content/TitanicImageDataset/True/221.png
#   inflating: content/TitanicImageDataset/True/3298.png
#   inflating: content/TitanicImageDataset/True/6867.png
#   inflating: content/TitanicImageDataset/True/7174.png
#   inflating: content/TitanicImageDataset/True/3906.png
#   inflating: content/TitanicImageDataset/True/4092.png
#   inflating: content/TitanicImageDataset/True/546.png
#   inflating: content/TitanicImageDataset/True/4617.png
#   inflating: content/TitanicImageDataset/True/768.png
#   inflating: content/TitanicImageDataset/True/5454.png
#   inflating: content/TitanicImageDataset/True/8149.png
#   inflating: content/TitanicImageDataset/True/493.png
#   inflating: content/TitanicImageDataset/True/6694.png
#   inflating: content/TitanicImageDataset/True/5513.png
#   inflating: content/TitanicImageDataset/True/481.png
#   inflating: content/TitanicImageDataset/True/5171.png
#   inflating: content/TitanicImageDataset/True/4407.png
#   inflating: content/TitanicImageDataset/True/3382.png
#   inflating: content/TitanicImageDataset/True/7187.png
#   inflating: content/TitanicImageDataset/True/869.png
#   inflating: content/TitanicImageDataset/True/1832.png
#   inflating: content/TitanicImageDataset/True/8093.png
#   inflating: content/TitanicImageDataset/True/3032.png
#   inflating: content/TitanicImageDataset/True/8261.png
#   inflating: content/TitanicImageDataset/True/8030.png
#   inflating: content/TitanicImageDataset/True/1287.png
#   inflating: content/TitanicImageDataset/True/3461.png
#   inflating: content/TitanicImageDataset/True/2637.png
#   inflating: content/TitanicImageDataset/True/8282.png
#   inflating: content/TitanicImageDataset/True/4784.png
#   inflating: content/TitanicImageDataset/True/4867.png
#   inflating: content/TitanicImageDataset/True/2875.png
#   inflating: content/TitanicImageDataset/True/7485.png
#   inflating: content/TitanicImageDataset/True/6336.png
#   inflating: content/TitanicImageDataset/True/1924.png
#   inflating: content/TitanicImageDataset/True/5220.png
#   inflating: content/TitanicImageDataset/True/7182.png
#   inflating: content/TitanicImageDataset/True/1568.png
#   inflating: content/TitanicImageDataset/True/4113.png
#   inflating: content/TitanicImageDataset/True/5184.png
#   inflating: content/TitanicImageDataset/True/3912.png
#   inflating: content/TitanicImageDataset/True/2369.png
#   inflating: content/TitanicImageDataset/True/504.png
#   inflating: content/TitanicImageDataset/True/6991.png
#   inflating: content/TitanicImageDataset/True/2946.png
#   inflating: content/TitanicImageDataset/True/151.png
#   inflating: content/TitanicImageDataset/True/4905.png
#   inflating: content/TitanicImageDataset/True/4856.png
#   inflating: content/TitanicImageDataset/True/517.png
#   inflating: content/TitanicImageDataset/True/2898.png
#   inflating: content/TitanicImageDataset/True/5685.png
#   inflating: content/TitanicImageDataset/True/4031.png
#   inflating: content/TitanicImageDataset/True/2383.png
#   inflating: content/TitanicImageDataset/True/3329.png
#   inflating: content/TitanicImageDataset/True/6436.png
#   inflating: content/TitanicImageDataset/True/95.png
#   inflating: content/TitanicImageDataset/True/3990.png
#   inflating: content/TitanicImageDataset/True/1722.png
#   inflating: content/TitanicImageDataset/True/513.png
#   inflating: content/TitanicImageDataset/True/7374.png
#   inflating: content/TitanicImageDataset/True/2760.png
#   inflating: content/TitanicImageDataset/True/4106.png
#   inflating: content/TitanicImageDataset/True/2981.png
#   inflating: content/TitanicImageDataset/True/5735.png
#   inflating: content/TitanicImageDataset/True/4900.png
#   inflating: content/TitanicImageDataset/True/3297.png
#   inflating: content/TitanicImageDataset/True/6778.png
#   inflating: content/TitanicImageDataset/True/3420.png
#   inflating: content/TitanicImageDataset/True/5862.png
#   inflating: content/TitanicImageDataset/True/2578.png
#   inflating: content/TitanicImageDataset/True/674.png
#   inflating: content/TitanicImageDataset/True/5647.png
#   inflating: content/TitanicImageDataset/True/6096.png
#   inflating: content/TitanicImageDataset/True/3943.png
#   inflating: content/TitanicImageDataset/True/4157.png
#   inflating: content/TitanicImageDataset/True/745.png
#   inflating: content/TitanicImageDataset/True/3450.png
#   inflating: content/TitanicImageDataset/True/5893.png
#   inflating: content/TitanicImageDataset/True/4110.png
#   inflating: content/TitanicImageDataset/True/6938.png
#   inflating: content/TitanicImageDataset/True/2772.png
#   inflating: content/TitanicImageDataset/True/2901.png
#   inflating: content/TitanicImageDataset/True/304.png
#   inflating: content/TitanicImageDataset/True/8648.png
#   inflating: content/TitanicImageDataset/True/6445.png
#   inflating: content/TitanicImageDataset/True/3693.png
#   inflating: content/TitanicImageDataset/True/2252.png
#   inflating: content/TitanicImageDataset/True/4091.png
#   inflating: content/TitanicImageDataset/True/2083.png
#   inflating: content/TitanicImageDataset/True/8595.png
#   inflating: content/TitanicImageDataset/True/5101.png
#   inflating: content/TitanicImageDataset/True/744.png
#   inflating: content/TitanicImageDataset/True/4970.png
#   inflating: content/TitanicImageDataset/True/1526.png
#   inflating: content/TitanicImageDataset/True/684.png
#   inflating: content/TitanicImageDataset/True/6721.png
#   inflating: content/TitanicImageDataset/True/7605.png
#   inflating: content/TitanicImageDataset/True/6200.png
#   inflating: content/TitanicImageDataset/True/3547.png
#   inflating: content/TitanicImageDataset/True/1653.png
#   inflating: content/TitanicImageDataset/True/4549.png
#   inflating: content/TitanicImageDataset/True/87.png
#   inflating: content/TitanicImageDataset/True/3940.png
#   inflating: content/TitanicImageDataset/True/7911.png
#   inflating: content/TitanicImageDataset/True/6563.png
#   inflating: content/TitanicImageDataset/True/2934.png
#   inflating: content/TitanicImageDataset/True/527.png
#   inflating: content/TitanicImageDataset/True/7518.png
#   inflating: content/TitanicImageDataset/True/2890.png
#   inflating: content/TitanicImageDataset/True/5264.png
#   inflating: content/TitanicImageDataset/True/6246.png
#   inflating: content/TitanicImageDataset/True/6023.png
#   inflating: content/TitanicImageDataset/True/470.png
#   inflating: content/TitanicImageDataset/True/5977.png
#   inflating: content/TitanicImageDataset/True/4806.png
#   inflating: content/TitanicImageDataset/True/2808.png
#   inflating: content/TitanicImageDataset/False/8190.png
#   inflating: content/TitanicImageDataset/False/2459.png
#   inflating: content/TitanicImageDataset/False/2931.png
#   inflating: content/TitanicImageDataset/False/7897.png
#   inflating: content/TitanicImageDataset/False/4749.png
#   inflating: content/TitanicImageDataset/False/4755.png
#   inflating: content/TitanicImageDataset/False/5219.png
#   inflating: content/TitanicImageDataset/False/735.png

# %%
import splitfolders  # or import split_folders
splitfolders.ratio("/content/content/TitanicImageDataset", output="/content/content/TitanicSplit", seed=1337, ratio=(.80,  .20), group_prefix=None) # default values
# Out:
# Copying files: 8693 files [00:00, 9675.51 files/s]

# %%
import os
os.listdir("/content/content/TitanicSplit")
# Out:
# ['train', 'val']

# %%
# Data augmentation and normalization for training
# Just normalization/content/content/HeartDiseasesdataset for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(128),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/content/content/TitanicSplit/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataset_sizes, class_names, device
# Out:
# ({'train': 6954, 'val': 1739}, ['False', 'True'], device(type='cuda', index=0))

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.datasets import fetch_openml

# %%
def train_simple_network_with_input_reshape(model, loss_func, train_loader, val_loader=None, score_funcs=None, 
                                            epochs=25, device="cpu", checkpoint_file=None):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    val_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    Here used the method provided in lecture only added code to flatten the inputs before passing to linear model
    """
    to_track = ["epoch", "total time", "train loss"]
    if val_loader is not None:
        to_track.append("val loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if val_loader is not None:
            to_track.append("val " + eval_score )
        
    total_train_time = 0 #How long have we spent in the training loop? 
    results = {}
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
    
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    for epoch in tqdm(range(epochs), desc="Epoch"):
    
        model = model.train()#Put our model in training mode
        running_loss = 0.0
        
        y_true = []
        y_pred = []

        start = time.time()
        for inputs, labels in tqdm(train_loader, desc="Train Batch", leave=False):
      
            #Move the batch to the device we are using. 
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            batch_size = inputs.shape[0]

            # PyTorch stores gradients in a mutable data structure. So we need to set it to a clean state before we use it. 
            #Otherwise, it will have old information from a previous iteration
            optimizer.zero_grad()

            #flatten the input to fit in linear model
            y_hat = model(inputs) #this just computed f_Θ(x(i))#pass in a flattened view of inputs

            # Compute loss.
            loss = loss_func(y_hat, labels)

            loss.backward()# ∇_Θ just got computed by this one call!

            #Now we just need to update all the parameters! 
            optimizer.step()# Θ_{k+1} = Θ_k − η * ∇_Θ ℓ(y_hat, y)

            #Now we are just grabbing some information we would like to have
            running_loss += loss.item() * inputs.size(0)
            
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            for i in range(batch_size):
                y_true.append(labels[i])
                y_pred.append(y_hat[i,:])
        #end training epoch
        end = time.time()
        total_train_time += (end-start)
        
        results["epoch"].append( epoch )
        results["total time"].append( total_train_time )
        results["train loss"].append( running_loss )
        
        y_pred = np.asarray(y_pred)
        
        if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
            y_pred = np.argmax(y_pred, axis=1)
            
        for name, score_func in score_funcs.items():
            results["train " + name].append( score_func(y_true, y_pred) )
      
        if val_loader is None:
            pass
        else:#Lets find out validation performance as we go!
            model = model.eval() #Set the model to "evaluation" mode, b/c we don't want to make any updates!

            y_true = []
            y_pred = []
            
            running_loss = 0.0

            for inputs, labels in val_loader:
        
                #Move the batch to the device we are using. 
                inputs = inputs.to(device)
                labels = labels.to(device)

                #flatten the input to fit in linear model
                y_hat = model(inputs) #pass in a flattened view of inputs
            
                loss = loss_func(y_hat, labels)
                
                #Now we are just grabbing some information we would like to have
                running_loss += loss.item() * inputs.size(0)

                #moving labels & predictions back to CPU for computing / storing predictions
                labels = labels.detach().cpu().numpy()
                y_hat = y_hat.detach().cpu().numpy()
                for i in range(batch_size):
                    y_true.append(labels[i])
                    y_pred.append(y_hat[i,:])
                        
            results["val loss"].append( running_loss )

            y_pred = np.asarray(y_pred)

            if y_pred.shape[1] > 1: #We have a classification problem, convert to labels
                y_pred = np.argmax(y_pred, axis=1)

            for name, score_func in score_funcs.items():
                results["val " + name].append( score_func(y_true, y_pred) )
                
        if checkpoint_file is not None:
            torch.save({
                'epoch': epoch,
                'c': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'results' : results
                }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    res_dict = {}
    epoch_loss_list = []
    epoch_acc_list = []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            epoch_loss_list.append(epoch_loss)
            epoch_acc_list.append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            res_dict[phase] = epoch_acc_list
            


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, epoch_loss_list, epoch_acc_list,res_dict

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
#Resnet Function with parameters as input


model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.3)
#optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0005)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=3, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
model_ft, ep_loss, ep_acc, res_dict = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.3064 Acc: 0.8921
# val Loss: 0.0569 Acc: 1.0000
#
# Epoch 1/4
# ----------
# train Loss: 0.0392 Acc: 0.9981
# val Loss: 0.0106 Acc: 1.0000
#
# Epoch 2/4
# ----------
# train Loss: 0.0152 Acc: 0.9996
# val Loss: 0.0051 Acc: 1.0000
#
# Epoch 3/4
# ----------
# train Loss: 0.0100 Acc: 1.0000
# val Loss: 0.0041 Acc: 1.0000
#
# Epoch 4/4
# ----------
# train Loss: 0.0096 Acc: 0.9999
# val Loss: 0.0039 Acc: 1.0000
#
# Training complete in 1m 17s
# Best val Acc: 1.000000
